# %%
import MomVectorBacktester as Mom

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2009-1-1', '2009-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 40
# Absolute performance: 10199.31656189483
# (np.float64(10199.32), np.float64(-227.74))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 40
# Absolute performance: 10199.31656189483
# Number of trades: 24
# Absolute performance: 10428.753854610315
# Number of trades: 34
# Absolute performance: 8281.465013191897
# Number of trades: 33
# Absolute performance: 9470.142153888903
# Number of trades: 21
# Absolute performance: 9954.512836756385
# Number of trades: 23
# Absolute performance: 10162.98741124394
# Number of trades: 13
# Absolute performance: 11263.05872112751
# Number of trades: 15
# Absolute performance: 9240.611653875203
# Number of trades: 9
# Absolute performance: 9592.656571099636
# Number of trades: 5
# Absolute performance: 10359.711339282598
# (70, np.float64(11263.06))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2008-10-10', '2009-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=70)
# Out:
# Number of trades: 14
# Absolute performance: 11157.625877027978
# (np.float64(11157.63), np.float64(913.6))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY',  '2018-12-15', '2019-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 45
# Absolute performance: 9376.326668317306
# (np.float64(9376.33), np.float64(-599.89))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 45
# Absolute performance: 9376.326668317306
# Number of trades: 29
# Absolute performance: 9872.275419497917
# Number of trades: 17
# Absolute performance: 9326.912950023077
# Number of trades: 14
# Absolute performance: 9955.624604313318
# Number of trades: 8
# Absolute performance: 10111.22953165009
# Number of trades: 10
# Absolute performance: 10027.525686332821
# Number of trades: 14
# Absolute performance: 9816.234213977494
# Number of trades: 16
# Absolute performance: 9538.011146817233
# Number of trades: 12
# Absolute performance: 9848.130064156127
# Number of trades: 14
# Absolute performance: 9831.882960738974
# (50, np.float64(10111.23))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY',  '2018-10-15', '2019-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=50)
# Out:
# Number of trades: 8
# Absolute performance: 10131.908569288917
# (np.float64(10131.91), np.float64(365.05))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2025-12-15', '2026-7-7', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 19
# Absolute performance: 9352.642383426606
# (np.float64(9352.64), np.float64(-1011.57))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 19
# Absolute performance: 9352.642383426606
# Number of trades: 17
# Absolute performance: 9953.079847239102
# Number of trades: 12
# Absolute performance: 9528.111542815466
# Number of trades: 14
# Absolute performance: 9349.567639337687
# Number of trades: 11
# Absolute performance: 10248.272515592475
# Number of trades: 3
# Absolute performance: 10117.121895883898
# Number of trades: 3
# Absolute performance: 10105.387227682259
# Number of trades: 3
# Absolute performance: 9948.054233021048
# Number of trades: 7
# Absolute performance: 10039.865020915231
# Number of trades: 3
# Absolute performance: 10330.46629285116
# (100, np.float64(10330.47))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2025-8-10', '2026-7-7', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=100)
# Out:
# Number of trades: 5
# Absolute performance: 10265.667413631585
# (np.float64(10265.67), np.float64(-98.54))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H4')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 109
# Absolute performance: 10280.670495255737
# (np.float64(10280.67), np.float64(-63.02))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((5,20,1))
# Out:
# Number of trades: 160
# Absolute performance: 10464.176980477829
# Number of trades: 140
# Absolute performance: 10685.429652296541
# Number of trades: 142
# Absolute performance: 10432.87198180103
# Number of trades: 131
# Absolute performance: 9720.87528560567
# Number of trades: 113
# Absolute performance: 10572.638957914498
# Number of trades: 109
# Absolute performance: 10280.670495255737
# Number of trades: 93
# Absolute performance: 9803.278809885618
# Number of trades: 93
# Absolute performance: 9606.030373947116
# Number of trades: 83
# Absolute performance: 9626.014021478552
# Number of trades: 97
# Absolute performance: 9583.792641546097
# Number of trades: 101
# Absolute performance: 9536.444786802314
# Number of trades: 95
# Absolute performance: 9880.156984220823
# Number of trades: 105
# Absolute performance: 9677.061474468412
# Number of trades: 87
# Absolute performance: 9549.274046906732
# Number of trades: 95
# Absolute performance: 9523.094491623386
# Number of trades: 67
# Absolute performance: 10123.804061400077
# (6, np.float64(10685.43))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H4')
mombt.run_strategy(momentum=6)
# Out:
# Number of trades: 140
# Absolute performance: 10685.429652296541
# (np.float64(10685.43), np.float64(386.67))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H1')
mombt.run_strategy(momentum=6)
# Out:
# Number of trades: 618
# Absolute performance: 9861.657191706223
# (np.float64(9861.66), np.float64(-449.58))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((3,10,1))
# Out:
# Number of trades: 934
# Absolute performance: 8944.382705496093
# Number of trades: 814
# Absolute performance: 8955.194284862164
# Number of trades: 699
# Absolute performance: 9401.625229044133
# Number of trades: 618
# Absolute performance: 9861.657191706223
# Number of trades: 582
# Absolute performance: 10254.449942137682
# Number of trades: 532
# Absolute performance: 10210.920507344954
# Number of trades: 512
# Absolute performance: 9838.12249794721
# Number of trades: 478
# Absolute performance: 9801.470435960813
# (7, np.float64(10254.45))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H1')
mombt.run_strategy(momentum=7)
# Out:
# Number of trades: 582
# Absolute performance: 10254.449942137682
# (np.float64(10254.45), np.float64(-51.01))

# %%
mombt.plot_results()
