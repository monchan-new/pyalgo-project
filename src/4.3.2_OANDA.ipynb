# %%
import MomVectorBacktester as Mom

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2002-5-6',
                                '2009-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 332
# Absolute performance: 10786.899842884775
# (np.float64(10786.9), np.float64(3400.37))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2002-5-6',
                                '2009-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=20)
# Out:
# Number of trades: 202
# Absolute performance: 10761.7208519615
# (np.float64(10761.72), np.float64(3223.15))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2002-5-6',
                                '2009-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=30)
# Out:
# Number of trades: 188
# Absolute performance: 8200.96550204365
# (np.float64(8200.97), np.float64(775.52))

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 332
# Absolute performance: 10786.899842884775
# Number of trades: 202
# Absolute performance: 10761.7208519615
# Number of trades: 188
# Absolute performance: 8200.96550204365
# Number of trades: 166
# Absolute performance: 8566.188264845987
# Number of trades: 156
# Absolute performance: 8894.50421336552
# Number of trades: 138
# Absolute performance: 10853.3719662222
# Number of trades: 124
# Absolute performance: 12657.63393510488
# Number of trades: 122
# Absolute performance: 7549.036918263761
# Number of trades: 108
# Absolute performance: 8850.87319160965
# Number of trades: 102
# Absolute performance: 9609.213911103458
# (70, np.float64(12657.63))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2002-5-6',
                                '2009-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=70)
# Out:
# Number of trades: 124
# Absolute performance: 12657.63393510488
# (np.float64(12657.63), np.float64(4827.16))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2010-1-1',
                                '2019-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 445
# Absolute performance: 9621.921091896818
# (np.float64(9621.92), np.float64(-2265.97))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2010-1-1',
                                '2019-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=20)
# Out:
# Number of trades: 281
# Absolute performance: 12201.296921525472
# (np.float64(12201.3), np.float64(166.29))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2010-1-1',
                                '2019-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=30)
# Out:
# Number of trades: 259
# Absolute performance: 11139.501477356778
# (np.float64(11139.5), np.float64(-800.66))

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 445
# Absolute performance: 9621.921091896818
# Number of trades: 281
# Absolute performance: 12201.296921525472
# Number of trades: 259
# Absolute performance: 11139.501477356778
# Number of trades: 232
# Absolute performance: 9720.446756220985
# Number of trades: 210
# Absolute performance: 13359.966960989917
# Number of trades: 152
# Absolute performance: 17280.556750978634
# Number of trades: 132
# Absolute performance: 13426.349880945174
# Number of trades: 145
# Absolute performance: 12649.161397439691
# Number of trades: 137
# Absolute performance: 12719.05327551039
# Number of trades: 124
# Absolute performance: 12548.348760661052
# (60, np.float64(17280.56))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2010-1-1',
                                '2019-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=60)
# Out:
# Number of trades: 152
# Absolute performance: 17280.556750978634
# (np.float64(17280.56), np.float64(5248.48))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2020-1-1',
                                '2026-7-11', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 230
# Absolute performance: 11743.862356811036
# (np.float64(11743.86), np.float64(-2933.91))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2020-1-1',
                                '2026-7-11', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=20)
# Out:
# Number of trades: 177
# Absolute performance: 11444.708711419154
# (np.float64(11444.71), np.float64(-3396.06))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2020-1-1',
                                '2026-7-11', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=30)
# Out:
# Number of trades: 137
# Absolute performance: 12601.3113520742
# (np.float64(12601.31), np.float64(-2122.43))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 230
# Absolute performance: 11743.862356811036
# Number of trades: 177
# Absolute performance: 11444.708711419154
# Number of trades: 137
# Absolute performance: 12601.3113520742
# Number of trades: 132
# Absolute performance: 11398.189831598733
# Number of trades: 86
# Absolute performance: 13267.142840453882
# Number of trades: 70
# Absolute performance: 14241.527788487909
# Number of trades: 61
# Absolute performance: 12753.737089323291
# Number of trades: 42
# Absolute performance: 13099.032843664072
# Number of trades: 50
# Absolute performance: 11840.844423635035
# Number of trades: 58
# Absolute performance: 10232.685267417457
# (60, np.float64(14241.53))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2020-1-1',
                                '2026-7-11', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=60)
# Out:
# Number of trades: 70
# Absolute performance: 14241.527788487909
# (np.float64(14241.53), np.float64(-508.94))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H4')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 109
# Absolute performance: 10280.670495255737
# (np.float64(10280.67), np.float64(-63.02))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((5,20,1))
# Out:
# Number of trades: 160
# Absolute performance: 10464.176980477829
# Number of trades: 140
# Absolute performance: 10685.429652296541
# Number of trades: 142
# Absolute performance: 10432.87198180103
# Number of trades: 131
# Absolute performance: 9720.87528560567
# Number of trades: 113
# Absolute performance: 10572.638957914498
# Number of trades: 109
# Absolute performance: 10280.670495255737
# Number of trades: 93
# Absolute performance: 9803.278809885618
# Number of trades: 93
# Absolute performance: 9606.030373947116
# Number of trades: 83
# Absolute performance: 9626.014021478552
# Number of trades: 97
# Absolute performance: 9583.792641546097
# Number of trades: 101
# Absolute performance: 9536.444786802314
# Number of trades: 95
# Absolute performance: 9880.156984220823
# Number of trades: 105
# Absolute performance: 9677.061474468412
# Number of trades: 87
# Absolute performance: 9549.274046906732
# Number of trades: 95
# Absolute performance: 9523.094491623386
# ...

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H4')
mombt.run_strategy(momentum=6)
# Out:
# Number of trades: 140
# Absolute performance: 10685.429652296541
# (np.float64(10685.43), np.float64(386.67))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H1')
mombt.run_strategy(momentum=6)
# Out:
# Number of trades: 618
# Absolute performance: 9861.657191706223
# (np.float64(9861.66), np.float64(-449.58))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((3,10,1))
# Out:
# Number of trades: 934
# Absolute performance: 8944.382705496093
# Number of trades: 814
# Absolute performance: 8955.194284862164
# Number of trades: 699
# Absolute performance: 9401.625229044133
# Number of trades: 618
# Absolute performance: 9861.657191706223
# Number of trades: 582
# Absolute performance: 10254.449942137682
# Number of trades: 532
# Absolute performance: 10210.920507344954
# Number of trades: 512
# Absolute performance: 9838.12249794721
# Number of trades: 478
# Absolute performance: 9801.470435960813
# (7, np.float64(10254.45))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H1')
mombt.run_strategy(momentum=7)
# Out:
# Number of trades: 582
# Absolute performance: 10254.449942137682
# (np.float64(10254.45), np.float64(-51.01))

# %%
mombt.plot_results()
