# %%
import MomVectorBacktester as Mom
mombt = Mom.MomVectorBacktester('USD_JPY', '2000-1-1',
                                '2010-1-1', 10000, 0.000025, 'D')

# %%
mombt.optimize_parameters((1,50,1))
# Out:
# Number of trades: 1360
# Absolute performance: 5334.457181701294
# Number of trades: 843
# Absolute performance: 13254.670172796528
# Number of trades: 716
# Absolute performance: 9632.842893019753
# Number of trades: 584
# Absolute performance: 9704.762687461955
# Number of trades: 532
# Absolute performance: 8065.913329266421
# Number of trades: 442
# Absolute performance: 8343.123392218404
# Number of trades: 374
# Absolute performance: 12305.673822137665
# Number of trades: 382
# Absolute performance: 9663.972659285277
# Number of trades: 350
# Absolute performance: 11081.666267774493
# Number of trades: 332
# Absolute performance: 10789.33491368972
# Number of trades: 316
# Absolute performance: 11633.30608766978
# Number of trades: 292
# Absolute performance: 10595.674297827087
# Number of trades: 288
# Absolute performance: 9895.92934539308
# Number of trades: 296
# Absolute performance: 11856.972226232201
# Number of trades: 280
# Absolute performance: 12692.715247890967
# ...

# %%
mombt.run_strategy(momentum=17)
# Out:
# Number of trades: 236
# Absolute performance: 14187.296542914582
# (np.float64(14187.3), np.float64(6728.92))

# %%
mombt.plot_results()

# %%
import MomVectorBacktester as Mom
mombt = Mom.MomVectorBacktester('USD_JPY', '2010-1-1',
                                '2020-1-1', 10000, 0.000025, "D")

# %%
mombt.optimize_parameters((1,50,1))
# Out:
# Number of trades: 1558
# Absolute performance: 10240.347680985313
# Number of trades: 962
# Absolute performance: 15593.208198518567
# Number of trades: 754
# Absolute performance: 14372.433084534576
# Number of trades: 676
# Absolute performance: 13383.984965534277
# Number of trades: 566
# Absolute performance: 10819.453897382427
# Number of trades: 530
# Absolute performance: 11506.799602879551
# Number of trades: 467
# Absolute performance: 11009.049843461493
# Number of trades: 423
# Absolute performance: 9696.574348118998
# Number of trades: 427
# Absolute performance: 9434.756277340104
# Number of trades: 445
# Absolute performance: 9621.921091896818
# Number of trades: 415
# Absolute performance: 8131.242874216387
# Number of trades: 407
# Absolute performance: 6563.7849271114255
# Number of trades: 376
# Absolute performance: 8051.689157892333
# Number of trades: 355
# Absolute performance: 11026.032273596535
# Number of trades: 360
# Absolute performance: 12109.40066727075
# ...

# %%
mombt.run_strategy(momentum=2)
# Out:
# Number of trades: 962
# Absolute performance: 15593.208198518567
# (np.float64(15593.21), np.float64(3747.71))

# %%
mombt.plot_results()

# %%
import MomVectorBacktester as Mom
mombt = Mom.MomVectorBacktester('USD_JPY', '2020-1-1',
                                '2026-7-1', 10000, 0.000025, "D")

# %%
mombt.optimize_parameters((1,50,1))
# Out:
# Number of trades: 858
# Absolute performance: 9399.828578581137
# Number of trades: 571
# Absolute performance: 12110.840847956077
# Number of trades: 467
# Absolute performance: 8081.329659434444
# Number of trades: 379
# Absolute performance: 9128.74487426997
# Number of trades: 341
# Absolute performance: 10031.584773650487
# Number of trades: 305
# Absolute performance: 9000.735449727257
# Number of trades: 309
# Absolute performance: 8882.65900740418
# Number of trades: 285
# Absolute performance: 9196.181229380021
# Number of trades: 247
# Absolute performance: 11507.297837948408
# Number of trades: 227
# Absolute performance: 11848.332423394872
# Number of trades: 233
# Absolute performance: 13303.050549148922
# Number of trades: 205
# Absolute performance: 13926.77690195928
# Number of trades: 205
# Absolute performance: 14575.415811195462
# Number of trades: 179
# Absolute performance: 15276.593743152349
# Number of trades: 175
# Absolute performance: 12256.716322885297
# ...

# %%
mombt.run_strategy(momentum=14)
# Out:
# Number of trades: 179
# Absolute performance: 15276.593743152349
# (np.float64(15276.59), np.float64(472.79))

# %%
mombt.plot_results()

# %%
import MomVectorBacktester as Mom
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-1', 10000, 0.000025, "H4")

# %%
mombt.optimize_parameters((1,50,1))
# Out:
# Number of trades: 400
# Absolute performance: 10154.426116954975
# Number of trades: 262
# Absolute performance: 10540.099631349196
# Number of trades: 228
# Absolute performance: 10020.112420729574
# Number of trades: 180
# Absolute performance: 10691.22910611787
# Number of trades: 155
# Absolute performance: 10334.431510052184
# Number of trades: 133
# Absolute performance: 10521.149308092328
# Number of trades: 137
# Absolute performance: 10276.408435906656
# Number of trades: 126
# Absolute performance: 9623.13706031367
# Number of trades: 108
# Absolute performance: 10460.782840650942
# Number of trades: 102
# Absolute performance: 10211.00367310764
# Number of trades: 90
# Absolute performance: 9932.614727699816
# Number of trades: 90
# Absolute performance: 9769.700762697728
# Number of trades: 80
# Absolute performance: 9808.135229347175
# Number of trades: 94
# Absolute performance: 9799.617007724224
# Number of trades: 98
# Absolute performance: 9731.501313392571
# ...

# %%
mombt.run_strategy(momentum=4)
# Out:
# Number of trades: 180
# Absolute performance: 10691.22910611787
# (np.float64(10691.23), np.float64(313.99))

# %%
mombt.plot_results()
