# %%
import MomVectorBacktester as Mom

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2002-5-6',
                                '2005-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 156
# Absolute performance: 11099.671073144329
# (np.float64(11099.67), np.float64(1749.98))

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 156
# Absolute performance: 11099.671073144329
# Number of trades: 93
# Absolute performance: 9585.858973554854
# Number of trades: 97
# Absolute performance: 8345.8517563195
# Number of trades: 69
# Absolute performance: 8897.549150167684
# Number of trades: 94
# Absolute performance: 7339.992505289376
# Number of trades: 72
# Absolute performance: 9070.422428945018
# Number of trades: 60
# Absolute performance: 10702.701883001271
# Number of trades: 70
# Absolute performance: 8236.008419085567
# Number of trades: 52
# Absolute performance: 9113.91374622916
# Number of trades: 50
# Absolute performance: 10113.79305713994
# (10, np.float64(11099.67))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2006-1-1',
                                '2009-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 176
# Absolute performance: 9695.997565795495
# (np.float64(9696.0), np.float64(1561.94))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2010-1-1',
                                '2015-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 289
# Absolute performance: 9113.554924731505
# (np.float64(9113.55), np.float64(-4041.72))

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 289
# Absolute performance: 9113.554924731505
# Number of trades: 169
# Absolute performance: 11229.120415162193
# Number of trades: 183
# Absolute performance: 10597.588930122396
# Number of trades: 161
# Absolute performance: 9561.648889541919
# Number of trades: 154
# Absolute performance: 11350.598368306148
# Number of trades: 102
# Absolute performance: 14221.896410815138
# Number of trades: 91
# Absolute performance: 10651.973055723858
# Number of trades: 96
# Absolute performance: 12430.644192299931
# Number of trades: 94
# Absolute performance: 11359.717557854507
# Number of trades: 79
# Absolute performance: 12162.7798398666
# (60, np.float64(14221.9))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2015-1-1',
                                '2019-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=60)
# Out:
# Number of trades: 57
# Absolute performance: 12150.452217698175
# (np.float64(12150.45), np.float64(3031.7))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2020-1-1',
                                '2023-12-31', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 142
# Absolute performance: 12025.17327349509
# (np.float64(12025.17), np.float64(-776.41))

# %%
mombt.optimize_parameters((10,100,10))
# Out:
# Number of trades: 142
# Absolute performance: 12025.17327349509
# Number of trades: 100
# Absolute performance: 11719.676363019318
# Number of trades: 88
# Absolute performance: 11356.748979999511
# Number of trades: 85
# Absolute performance: 12070.43900452381
# Number of trades: 53
# Absolute performance: 12294.533453112828
# Number of trades: 51
# Absolute performance: 13272.14460580642
# Number of trades: 36
# Absolute performance: 13112.644018906643
# Number of trades: 25
# Absolute performance: 13819.316216505755
# Number of trades: 25
# Absolute performance: 12398.765017579946
# Number of trades: 29
# Absolute performance: 11237.60679699242
# (80, np.float64(13819.32))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2024-1-1',
                                '2026-7-7', 10000, 0.000025, 'D')
mombt.run_strategy(momentum=80)
# Out:
# Number of trades: 11
# Absolute performance: 10008.652615065585
# (np.float64(10008.65), np.float64(-461.65))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H4')
mombt.run_strategy(momentum=10)
# Out:
# Number of trades: 109
# Absolute performance: 10280.670495255737
# (np.float64(10280.67), np.float64(-63.02))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((5,20,1))
# Out:
# Number of trades: 160
# Absolute performance: 10464.176980477829
# Number of trades: 140
# Absolute performance: 10685.429652296541
# Number of trades: 142
# Absolute performance: 10432.87198180103
# Number of trades: 131
# Absolute performance: 9720.87528560567
# Number of trades: 113
# Absolute performance: 10572.638957914498
# Number of trades: 109
# Absolute performance: 10280.670495255737
# Number of trades: 93
# Absolute performance: 9803.278809885618
# Number of trades: 93
# Absolute performance: 9606.030373947116
# Number of trades: 83
# Absolute performance: 9626.014021478552
# Number of trades: 97
# Absolute performance: 9583.792641546097
# Number of trades: 101
# Absolute performance: 9536.444786802314
# Number of trades: 95
# Absolute performance: 9880.156984220823
# Number of trades: 105
# Absolute performance: 9677.061474468412
# Number of trades: 87
# Absolute performance: 9549.274046906732
# Number of trades: 95
# Absolute performance: 9523.094491623386
# Number of trades: 67
# Absolute performance: 10123.804061400077
# (6, np.float64(10685.43))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H4')
mombt.run_strategy(momentum=6)
# Out:
# Number of trades: 140
# Absolute performance: 10685.429652296541
# (np.float64(10685.43), np.float64(386.67))

# %%
mombt.plot_results()

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H1')
mombt.run_strategy(momentum=6)
# Out:
# Number of trades: 618
# Absolute performance: 9861.657191706223
# (np.float64(9861.66), np.float64(-449.58))

# %%
mombt.plot_results()

# %%
mombt.optimize_parameters((3,10,1))
# Out:
# Number of trades: 934
# Absolute performance: 8944.382705496093
# Number of trades: 814
# Absolute performance: 8955.194284862164
# Number of trades: 699
# Absolute performance: 9401.625229044133
# Number of trades: 618
# Absolute performance: 9861.657191706223
# Number of trades: 582
# Absolute performance: 10254.449942137682
# Number of trades: 532
# Absolute performance: 10210.920507344954
# Number of trades: 512
# Absolute performance: 9838.12249794721
# Number of trades: 478
# Absolute performance: 9801.470435960813
# (7, np.float64(10254.45))

# %%
mombt = Mom.MomVectorBacktester('USD_JPY', '2026-1-1',
                                '2026-7-11', 10000, 0.000025, 'H1')
mombt.run_strategy(momentum=7)
# Out:
# Number of trades: 582
# Absolute performance: 10254.449942137682
# (np.float64(10254.45), np.float64(-51.01))

# %%
mombt.plot_results()
