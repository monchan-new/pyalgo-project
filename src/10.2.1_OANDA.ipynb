# %%
import AdaBoostVectorBacktester as AB

# %%
abbt = AB.AdaBoostVectorBacktester('EUR_USD',
                                   '2020-06-08', '2020-06-13', 1)

# %%
abbt.run_strategy(
    '2020-06-08', '2020-06-11 11:00:00',  
    '2020-06-11 11:10:00', '2020-06-13')
# Out:
# rerurns, strategy= returns     0.990182
# strategy    0.993988
# dtype: float64
# strategy_tc= strategy    0.986326
# dtype: float64
# (np.float64(0.99), np.float64(-0.0))

# %%
abbt.plot_results()

# %%
abbt.run_strategy(
    '2020-06-08 5:20:00', '2020-06-11 11:20:00',  
    '2020-06-11 11:30:00', '2020-06-13')
# Out:
# rerurns, strategy= returns     0.990592
# strategy    1.016910
# dtype: float64
# strategy_tc= strategy    1.011213
# dtype: float64
# (np.float64(1.01), np.float64(0.02))

# %%
abbt.plot_results()

# %%
abbt.run_strategy(
    '2020-06-08', '2020-06-13',  
    '2020-06-08', '2020-06-13')
# Out:
# rerurns, strategy= returns     0.996847
# strategy    1.113258
# dtype: float64
# strategy_tc= strategy    1.081391
# dtype: float64
# (np.float64(1.08), np.float64(0.08))

# %%
abbt.plot_results()
