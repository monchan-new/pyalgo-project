# %%
import SMAVectorBacktester as SMA

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 20, 50, '2002-5-6', '2005-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 20 50
# Absolute performance: 0.7441675867923497
# (np.float64(0.74), np.float64(-0.24))

# %%
# %%time
smabt.optimize_parameters((10,50,5), (50,200,5))
# Out:
# SMA1 & SMA2: 10 50
# Absolute performance: 0.8042415322529055
# SMA1 & SMA2: 10 55
# Absolute performance: 0.8085079249739081
# SMA1 & SMA2: 10 60
# Absolute performance: 0.799458211810599
# SMA1 & SMA2: 10 65
# Absolute performance: 0.8091668360419957
# SMA1 & SMA2: 10 70
# Absolute performance: 0.8186529414825072
# SMA1 & SMA2: 10 75
# Absolute performance: 0.8801827469291481
# SMA1 & SMA2: 10 80
# Absolute performance: 0.8918155398509052
# SMA1 & SMA2: 10 85
# Absolute performance: 0.8241133387509886
# SMA1 & SMA2: 10 90
# Absolute performance: 0.7956707743546383
# SMA1 & SMA2: 10 95
# Absolute performance: 0.7849481883989486
# SMA1 & SMA2: 10 100
# Absolute performance: 0.7981321373102905
# SMA1 & SMA2: 10 105
# Absolute performance: 0.8225695290618361
# SMA1 & SMA2: 10 110
# Absolute performance: 0.8350494149816544
# SMA1 & SMA2: 10 115
# Absolute performance: 0.8525144153920348
# SMA1 & SMA2: 10 120
# Absolute performance: 0.8621817002790167
# SMA1 & SMA2: 10 125
# Absolute performance: 0.9338528855474935
# SMA1 & SMA2: 10 130
# Absolute performance: 0.9334307951040712
# SMA1 & SMA2: 10 135
# Absolute performance: 0.892461312523735
# SMA1 & SMA2: 10 140
# Absolute performance: 0.947444473241227
# SMA1 & SMA2: 10 145
# Absolute performance: 0.9281133077651486
# SMA1 & SMA2: 10 150
# Absolute performance: 0.9391664417965568
# SMA1 & SMA2: 10 155
# Absolute performance: 0.92964202594679
# SMA1 & SMA2: 10 160
# Absolute performance: 0.995587820370497
# SMA1 & SMA2: 10 165
# Absolute performance: 1.0210122042743828
# SMA1 & SMA2: 10 170
# Absolute performance: 1.0364677711201329
# SMA1 & SMA2: 10 175
# Absolute performance: 1.0647772981008747
# SMA1 & SMA2: 10 180
# Absolute performance: 1.0351964874970954
# SMA1 & SMA2: 10 185
# Absolute performance: 1.0279046379317054
# SMA1 & SMA2: 10 190
# Absolute performance: 1.0471543389456137
# SMA1 & SMA2: 10 195
# Absolute performance: 1.0256919959811495
# SMA1 & SMA2: 15 50
# Absolute performance: 0.8424857958652028
# SMA1 & SMA2: 15 55
# Absolute performance: 0.7896858645882834
# SMA1 & SMA2: 15 60
# Absolute performance: 0.7900794964292539
# SMA1 & SMA2: 15 65
# Absolute performance: 0.7662847674404959
# SMA1 & SMA2: 15 70
# Absolute performance: 0.7996411562631982
# SMA1 & SMA2: 15 75
# Absolute performance: 0.8525739281183269
# SMA1 & SMA2: 15 80
# Absolute performance: 0.8361979620466062
# SMA1 & SMA2: 15 85
# Absolute performance: 0.8236768769935026
# SMA1 & SMA2: 15 90
# Absolute performance: 0.8619342539490026
# SMA1 & SMA2: 15 95
# Absolute performance: 0.8124425604182194
# SMA1 & SMA2: 15 100
# Absolute performance: 0.8407091577973476
# SMA1 & SMA2: 15 105
# Absolute performance: 0.81377337308366
# SMA1 & SMA2: 15 110
# Absolute performance: 0.8649908482747737
# SMA1 & SMA2: 15 115
# Absolute performance: 0.8907253087391104
# SMA1 & SMA2: 15 120
# Absolute performance: 0.9290846866265364
# SMA1 & SMA2: 15 125
# Absolute performance: 0.9350397069479194
# SMA1 & SMA2: 15 130
# Absolute performance: 0.9722513947321303
# SMA1 & SMA2: 15 135
# Absolute performance: 0.9581777783647321
# SMA1 & SMA2: 15 140
# Absolute performance: 0.9532693730912197
# SMA1 & SMA2: 15 145
# Absolute performance: 0.9784866744909345
# SMA1 & SMA2: 15 150
# Absolute performance: 0.9816798372426548
# SMA1 & SMA2: 15 155
# Absolute performance: 0.9589286612520375
# SMA1 & SMA2: 15 160
# Absolute performance: 0.969574510208178
# SMA1 & SMA2: 15 165
# Absolute performance: 0.9777023986656962
# SMA1 & SMA2: 15 170
# Absolute performance: 1.0319264285290277
# SMA1 & SMA2: 15 175
# Absolute performance: 1.0174459705562926
# SMA1 & SMA2: 15 180
# Absolute performance: 1.0203712233550324
# SMA1 & SMA2: 15 185
# Absolute performance: 1.0275529036795719
# SMA1 & SMA2: 15 190
# Absolute performance: 1.0493818930615744
# SMA1 & SMA2: 15 195
# Absolute performance: 1.0034822337127176
# SMA1 & SMA2: 20 50
# Absolute performance: 0.7441675867923497
# SMA1 & SMA2: 20 55
# Absolute performance: 0.7641205671754464
# SMA1 & SMA2: 20 60
# Absolute performance: 0.7178629647872072
# SMA1 & SMA2: 20 65
# Absolute performance: 0.8099581245696645
# SMA1 & SMA2: 20 70
# Absolute performance: 0.8401302807801202
# SMA1 & SMA2: 20 75
# Absolute performance: 0.8768544666180833
# SMA1 & SMA2: 20 80
# Absolute performance: 0.8634006825158838
# SMA1 & SMA2: 20 85
# Absolute performance: 0.826035074907605
# SMA1 & SMA2: 20 90
# Absolute performance: 0.7964190192189917
# SMA1 & SMA2: 20 95
# Absolute performance: 0.795071572055589
# SMA1 & SMA2: 20 100
# Absolute performance: 0.8565538264390815
# SMA1 & SMA2: 20 105
# Absolute performance: 0.8373436867076296
# SMA1 & SMA2: 20 110
# Absolute performance: 0.869981490365943
# SMA1 & SMA2: 20 115
# Absolute performance: 0.8615546732738384
# SMA1 & SMA2: 20 120
# Absolute performance: 0.9126489154552926
# SMA1 & SMA2: 20 125
# Absolute performance: 0.8679795743704276
# SMA1 & SMA2: 20 130
# Absolute performance: 0.878440994423737
# SMA1 & SMA2: 20 135
# Absolute performance: 0.8590402081410362
# SMA1 & SMA2: 20 140
# Absolute performance: 0.8744147324380641
# SMA1 & SMA2: 20 145
# Absolute performance: 0.8899191249533281
# SMA1 & SMA2: 20 150
# Absolute performance: 0.9122573463908368
# SMA1 & SMA2: 20 155
# Absolute performance: 0.9186743216820235
# SMA1 & SMA2: 20 160
# Absolute performance: 0.9359501288889315
# SMA1 & SMA2: 20 165
# Absolute performance: 0.968034335367287
# SMA1 & SMA2: 20 170
# Absolute performance: 0.9654685028753619
# SMA1 & SMA2: 20 175
# Absolute performance: 0.9243270979088242
# SMA1 & SMA2: 20 180
# Absolute performance: 0.9686821116509445
# SMA1 & SMA2: 20 185
# Absolute performance: 0.9809889178510955
# SMA1 & SMA2: 20 190
# Absolute performance: 1.0378022865124739
# SMA1 & SMA2: 20 195
# Absolute performance: 1.0673302874647896
# SMA1 & SMA2: 25 50
# Absolute performance: 0.7033227978217518
# SMA1 & SMA2: 25 55
# Absolute performance: 0.8562899157868525
# SMA1 & SMA2: 25 60
# Absolute performance: 0.8636748464200087
# SMA1 & SMA2: 25 65
# Absolute performance: 0.841744064914164
# SMA1 & SMA2: 25 70
# Absolute performance: 0.8400578361332903
# SMA1 & SMA2: 25 75
# Absolute performance: 0.866856497961705
# SMA1 & SMA2: 25 80
# Absolute performance: 0.94788734825551
# SMA1 & SMA2: 25 85
# Absolute performance: 0.8425929059025645
# SMA1 & SMA2: 25 90
# Absolute performance: 0.7984552504055552
# SMA1 & SMA2: 25 95
# Absolute performance: 0.7862033521077209
# SMA1 & SMA2: 25 100
# Absolute performance: 0.8051821584282122
# SMA1 & SMA2: 25 105
# Absolute performance: 0.791179738970775
# SMA1 & SMA2: 25 110
# Absolute performance: 0.7894863339257228
# SMA1 & SMA2: 25 115
# Absolute performance: 0.8110242456118357
# SMA1 & SMA2: 25 120
# Absolute performance: 0.8313334828233325
# SMA1 & SMA2: 25 125
# Absolute performance: 0.8511558432207447
# SMA1 & SMA2: 25 130
# Absolute performance: 0.7983945810303638
# SMA1 & SMA2: 25 135
# Absolute performance: 0.8455989360670307
# SMA1 & SMA2: 25 140
# Absolute performance: 0.8194691621142425
# SMA1 & SMA2: 25 145
# Absolute performance: 0.8484669551934744
# SMA1 & SMA2: 25 150
# Absolute performance: 0.9207725416468162
# SMA1 & SMA2: 25 155
# Absolute performance: 0.9243142619277569
# SMA1 & SMA2: 25 160
# Absolute performance: 0.9451604130244851
# SMA1 & SMA2: 25 165
# Absolute performance: 0.9337790623871673
# SMA1 & SMA2: 25 170
# Absolute performance: 0.8995203159169478
# SMA1 & SMA2: 25 175
# Absolute performance: 0.9499056277510164
# SMA1 & SMA2: 25 180
# Absolute performance: 0.9791781785638786
# SMA1 & SMA2: 25 185
# Absolute performance: 1.0303821408845553
# SMA1 & SMA2: 25 190
# Absolute performance: 1.0508844337403667
# SMA1 & SMA2: 25 195
# Absolute performance: 1.0667128736928808
# SMA1 & SMA2: 30 50
# Absolute performance: 0.7702495329732539
# SMA1 & SMA2: 30 55
# Absolute performance: 0.7928990100228401
# SMA1 & SMA2: 30 60
# Absolute performance: 0.8495043034334019
# SMA1 & SMA2: 30 65
# Absolute performance: 0.8730346300541509
# SMA1 & SMA2: 30 70
# Absolute performance: 0.8337213679756789
# SMA1 & SMA2: 30 75
# Absolute performance: 0.9196828381091062
# SMA1 & SMA2: 30 80
# Absolute performance: 0.9073691670485694
# SMA1 & SMA2: 30 85
# Absolute performance: 0.8562310156302381
# SMA1 & SMA2: 30 90
# Absolute performance: 0.8345082067284029
# SMA1 & SMA2: 30 95
# Absolute performance: 0.8348913465361211
# SMA1 & SMA2: 30 100
# Absolute performance: 0.7792643416914063
# SMA1 & SMA2: 30 105
# Absolute performance: 0.8016979868575678
# SMA1 & SMA2: 30 110
# Absolute performance: 0.8527433035013728
# SMA1 & SMA2: 30 115
# Absolute performance: 0.842444023535803
# SMA1 & SMA2: 30 120
# Absolute performance: 0.9025188891422901
# SMA1 & SMA2: 30 125
# Absolute performance: 0.8474087581857569
# SMA1 & SMA2: 30 130
# Absolute performance: 0.8350193950690252
# SMA1 & SMA2: 30 135
# Absolute performance: 0.864907163762784
# SMA1 & SMA2: 30 140
# Absolute performance: 0.9434749927850621
# SMA1 & SMA2: 30 145
# Absolute performance: 0.97786856092195
# SMA1 & SMA2: 30 150
# Absolute performance: 0.9523307747656383
# SMA1 & SMA2: 30 155
# Absolute performance: 0.9489016641394967
# SMA1 & SMA2: 30 160
# Absolute performance: 1.0164929877607534
# SMA1 & SMA2: 30 165
# Absolute performance: 1.0399204247257163
# SMA1 & SMA2: 30 170
# Absolute performance: 0.9916482151816175
# SMA1 & SMA2: 30 175
# Absolute performance: 0.9674901360941438
# SMA1 & SMA2: 30 180
# Absolute performance: 1.008615155554523
# SMA1 & SMA2: 30 185
# Absolute performance: 1.0131162152346533
# SMA1 & SMA2: 30 190
# Absolute performance: 1.0144493431851973
# SMA1 & SMA2: 30 195
# Absolute performance: 1.0182501583927668
# SMA1 & SMA2: 35 50
# Absolute performance: 0.8345186330301766
# SMA1 & SMA2: 35 55
# Absolute performance: 0.8920032999840993
# SMA1 & SMA2: 35 60
# Absolute performance: 0.9393731309254554
# SMA1 & SMA2: 35 65
# Absolute performance: 0.9106923961056153
# SMA1 & SMA2: 35 70
# Absolute performance: 0.9416129812366101
# SMA1 & SMA2: 35 75
# Absolute performance: 0.9517073728424137
# SMA1 & SMA2: 35 80
# Absolute performance: 0.9351564329913362
# SMA1 & SMA2: 35 85
# Absolute performance: 0.9147011854623109
# SMA1 & SMA2: 35 90
# Absolute performance: 0.8797116693933285
# SMA1 & SMA2: 35 95
# Absolute performance: 0.8323975788022737
# SMA1 & SMA2: 35 100
# Absolute performance: 0.869578546096296
# SMA1 & SMA2: 35 105
# Absolute performance: 0.8581724497958987
# SMA1 & SMA2: 35 110
# Absolute performance: 0.8487355721548652
# SMA1 & SMA2: 35 115
# Absolute performance: 0.8992753800161929
# SMA1 & SMA2: 35 120
# Absolute performance: 0.9353471052108902
# SMA1 & SMA2: 35 125
# Absolute performance: 0.8903249884147817
# SMA1 & SMA2: 35 130
# Absolute performance: 0.9622496277991136
# SMA1 & SMA2: 35 135
# Absolute performance: 0.9472379529179836
# SMA1 & SMA2: 35 140
# Absolute performance: 0.9704312143871088
# SMA1 & SMA2: 35 145
# Absolute performance: 0.9122256316266701
# SMA1 & SMA2: 35 150
# Absolute performance: 0.938761916324611
# SMA1 & SMA2: 35 155
# Absolute performance: 1.0017442785380837
# SMA1 & SMA2: 35 160
# Absolute performance: 1.030595721073809
# SMA1 & SMA2: 35 165
# Absolute performance: 0.9894385135155275
# SMA1 & SMA2: 35 170
# Absolute performance: 0.9887383497110179
# SMA1 & SMA2: 35 175
# Absolute performance: 0.9712318420459125
# SMA1 & SMA2: 35 180
# Absolute performance: 0.909930594234984
# SMA1 & SMA2: 35 185
# Absolute performance: 0.93016651599983
# SMA1 & SMA2: 35 190
# Absolute performance: 0.9670077776547837
# SMA1 & SMA2: 35 195
# Absolute performance: 0.9749669680109307
# SMA1 & SMA2: 40 50
# Absolute performance: 0.8809057804143146
# SMA1 & SMA2: 40 55
# Absolute performance: 0.9844995302557701
# SMA1 & SMA2: 40 60
# Absolute performance: 0.993813343960322
# SMA1 & SMA2: 40 65
# Absolute performance: 1.0343237286232148
# SMA1 & SMA2: 40 70
# Absolute performance: 0.9564373600136087
# SMA1 & SMA2: 40 75
# Absolute performance: 0.9825179353425277
# SMA1 & SMA2: 40 80
# Absolute performance: 1.0052135409028824
# SMA1 & SMA2: 40 85
# Absolute performance: 0.9206009024535496
# SMA1 & SMA2: 40 90
# Absolute performance: 0.8887933884929764
# SMA1 & SMA2: 40 95
# Absolute performance: 0.890365509683217
# SMA1 & SMA2: 40 100
# Absolute performance: 0.8228240146283179
# SMA1 & SMA2: 40 105
# Absolute performance: 0.8317650823234268
# SMA1 & SMA2: 40 110
# Absolute performance: 0.863551400250704
# SMA1 & SMA2: 40 115
# Absolute performance: 0.8751058570152161
# SMA1 & SMA2: 40 120
# Absolute performance: 0.8926200324582827
# SMA1 & SMA2: 40 125
# Absolute performance: 0.89498618167104
# SMA1 & SMA2: 40 130
# Absolute performance: 0.9365608405876796
# SMA1 & SMA2: 40 135
# Absolute performance: 0.9853220102422954
# SMA1 & SMA2: 40 140
# Absolute performance: 1.0373715012029683
# SMA1 & SMA2: 40 145
# Absolute performance: 1.0826266673365443
# SMA1 & SMA2: 40 150
# Absolute performance: 1.1072152835578553
# SMA1 & SMA2: 40 155
# Absolute performance: 1.0339184778574826
# SMA1 & SMA2: 40 160
# Absolute performance: 1.0218982655907043
# SMA1 & SMA2: 40 165
# Absolute performance: 1.0065007582477212
# SMA1 & SMA2: 40 170
# Absolute performance: 0.9910246981691108
# SMA1 & SMA2: 40 175
# Absolute performance: 0.9497085310886004
# SMA1 & SMA2: 40 180
# Absolute performance: 0.9242992127742835
# SMA1 & SMA2: 40 185
# Absolute performance: 0.9294932912037407
# SMA1 & SMA2: 40 190
# Absolute performance: 0.9789333619146965
# SMA1 & SMA2: 40 195
# Absolute performance: 0.9770378921370614
# SMA1 & SMA2: 45 50
# Absolute performance: 0.9562576577338041
# SMA1 & SMA2: 45 55
# Absolute performance: 1.0160187528421771
# SMA1 & SMA2: 45 60
# Absolute performance: 0.9879341543408308
# SMA1 & SMA2: 45 65
# Absolute performance: 0.9416481339101503
# SMA1 & SMA2: 45 70
# Absolute performance: 0.9346919854713287
# SMA1 & SMA2: 45 75
# Absolute performance: 1.016395790518396
# SMA1 & SMA2: 45 80
# Absolute performance: 0.953805432221616
# SMA1 & SMA2: 45 85
# Absolute performance: 0.9729794702741972
# SMA1 & SMA2: 45 90
# Absolute performance: 0.8944379367416757
# SMA1 & SMA2: 45 95
# Absolute performance: 0.8808594291437577
# SMA1 & SMA2: 45 100
# Absolute performance: 0.8327066888570891
# SMA1 & SMA2: 45 105
# Absolute performance: 0.8807733072411915
# SMA1 & SMA2: 45 110
# Absolute performance: 0.9096073294330865
# SMA1 & SMA2: 45 115
# Absolute performance: 0.9152268145338147
# SMA1 & SMA2: 45 120
# Absolute performance: 0.9658315819056824
# SMA1 & SMA2: 45 125
# Absolute performance: 0.9886236131067223
# SMA1 & SMA2: 45 130
# Absolute performance: 0.9850226384992704
# SMA1 & SMA2: 45 135
# Absolute performance: 1.0761398187824602
# SMA1 & SMA2: 45 140
# Absolute performance: 1.1220192037534327
# SMA1 & SMA2: 45 145
# Absolute performance: 1.1462944589979378
# SMA1 & SMA2: 45 150
# Absolute performance: 1.1556358685339045
# SMA1 & SMA2: 45 155
# Absolute performance: 1.1308382192880437
# SMA1 & SMA2: 45 160
# Absolute performance: 1.0907616985754933
# SMA1 & SMA2: 45 165
# Absolute performance: 1.0979961712804376
# SMA1 & SMA2: 45 170
# Absolute performance: 0.9853934020619914
# SMA1 & SMA2: 45 175
# Absolute performance: 0.972478329375325
# SMA1 & SMA2: 45 180
# Absolute performance: 0.9349792631353566
# SMA1 & SMA2: 45 185
# Absolute performance: 0.92222356526928
# SMA1 & SMA2: 45 190
# Absolute performance: 0.9741158997454478
# SMA1 & SMA2: 45 195
# Absolute performance: 0.9778511967131152
# SMA1 & SMA2: 45 150
# Absolute performance: 1.1556358685339045
# CPU times: user 373 ms, sys: 661 μs, total: 374 ms
# Wall time: 371 ms
# (array([ 45., 150.]), np.float64(1.16))

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 45, 150, '2006-1-1', '2009-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 45 150
# Absolute performance: 1.0168402510421046
# (np.float64(1.02), np.float64(0.21))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 20, 50, '2010-1-1', '2014-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 20 50
# Absolute performance: 1.0470296926250864
# (np.float64(1.05), np.float64(-0.26))

# %%
# %%time
smabt.optimize_parameters((10,50,5), (50,200,5))
# Out:
# SMA1 & SMA2: 10 50
# Absolute performance: 1.1088949816204652
# SMA1 & SMA2: 10 55
# Absolute performance: 1.1043965373927869
# SMA1 & SMA2: 10 60
# Absolute performance: 1.1186973403823652
# SMA1 & SMA2: 10 65
# Absolute performance: 1.117632308925015
# SMA1 & SMA2: 10 70
# Absolute performance: 1.1416713338277327
# SMA1 & SMA2: 10 75
# Absolute performance: 1.216450304783339
# SMA1 & SMA2: 10 80
# Absolute performance: 1.0864827067999137
# SMA1 & SMA2: 10 85
# Absolute performance: 1.1306774147428824
# SMA1 & SMA2: 10 90
# Absolute performance: 1.10711273682706
# SMA1 & SMA2: 10 95
# Absolute performance: 1.130105090247686
# SMA1 & SMA2: 10 100
# Absolute performance: 1.1194583315160482
# SMA1 & SMA2: 10 105
# Absolute performance: 1.1024065971337158
# SMA1 & SMA2: 10 110
# Absolute performance: 1.1397095007727855
# SMA1 & SMA2: 10 115
# Absolute performance: 1.220979928988319
# SMA1 & SMA2: 10 120
# Absolute performance: 1.2532124208298419
# SMA1 & SMA2: 10 125
# Absolute performance: 1.2236388310874065
# SMA1 & SMA2: 10 130
# Absolute performance: 1.2532308058503654
# SMA1 & SMA2: 10 135
# Absolute performance: 1.3249854981899882
# SMA1 & SMA2: 10 140
# Absolute performance: 1.2902585217161655
# SMA1 & SMA2: 10 145
# Absolute performance: 1.32833561081059
# SMA1 & SMA2: 10 150
# Absolute performance: 1.4099295120843793
# SMA1 & SMA2: 10 155
# Absolute performance: 1.4261299229620934
# SMA1 & SMA2: 10 160
# Absolute performance: 1.375264989768892
# SMA1 & SMA2: 10 165
# Absolute performance: 1.3416943283089648
# SMA1 & SMA2: 10 170
# Absolute performance: 1.373294898577309
# SMA1 & SMA2: 10 175
# Absolute performance: 1.3194832101772702
# SMA1 & SMA2: 10 180
# Absolute performance: 1.3313730035676241
# SMA1 & SMA2: 10 185
# Absolute performance: 1.3382773225109694
# SMA1 & SMA2: 10 190
# Absolute performance: 1.3519034834315575
# SMA1 & SMA2: 10 195
# Absolute performance: 1.3896178416402356
# SMA1 & SMA2: 15 50
# Absolute performance: 1.0782346229289488
# SMA1 & SMA2: 15 55
# Absolute performance: 1.0418998521635645
# SMA1 & SMA2: 15 60
# Absolute performance: 1.1020839684610846
# SMA1 & SMA2: 15 65
# Absolute performance: 1.2093312018342215
# SMA1 & SMA2: 15 70
# Absolute performance: 1.2491533357665965
# SMA1 & SMA2: 15 75
# Absolute performance: 1.2690638586251388
# SMA1 & SMA2: 15 80
# Absolute performance: 1.1531937061820863
# SMA1 & SMA2: 15 85
# Absolute performance: 1.2137880627001598
# SMA1 & SMA2: 15 90
# Absolute performance: 1.1694745577213863
# SMA1 & SMA2: 15 95
# Absolute performance: 1.1260822721410055
# SMA1 & SMA2: 15 100
# Absolute performance: 1.1914853039335573
# SMA1 & SMA2: 15 105
# Absolute performance: 1.082848814437623
# SMA1 & SMA2: 15 110
# Absolute performance: 1.1321947182703043
# SMA1 & SMA2: 15 115
# Absolute performance: 1.265383608637831
# SMA1 & SMA2: 15 120
# Absolute performance: 1.1971106811936516
# SMA1 & SMA2: 15 125
# Absolute performance: 1.2434138549567346
# SMA1 & SMA2: 15 130
# Absolute performance: 1.2175557628139935
# SMA1 & SMA2: 15 135
# Absolute performance: 1.2290798403288052
# SMA1 & SMA2: 15 140
# Absolute performance: 1.2517574066182187
# SMA1 & SMA2: 15 145
# Absolute performance: 1.3263720615361876
# SMA1 & SMA2: 15 150
# Absolute performance: 1.3471120656643865
# SMA1 & SMA2: 15 155
# Absolute performance: 1.3216481282053192
# SMA1 & SMA2: 15 160
# Absolute performance: 1.356873433547943
# SMA1 & SMA2: 15 165
# Absolute performance: 1.3957696213280724
# SMA1 & SMA2: 15 170
# Absolute performance: 1.4080934761157082
# SMA1 & SMA2: 15 175
# Absolute performance: 1.4013372295335158
# SMA1 & SMA2: 15 180
# Absolute performance: 1.3707394306178031
# SMA1 & SMA2: 15 185
# Absolute performance: 1.395645936467161
# SMA1 & SMA2: 15 190
# Absolute performance: 1.3333026689531742
# SMA1 & SMA2: 15 195
# Absolute performance: 1.3751126455865474
# SMA1 & SMA2: 20 50
# Absolute performance: 1.0470296926250864
# SMA1 & SMA2: 20 55
# Absolute performance: 1.0586203891435302
# SMA1 & SMA2: 20 60
# Absolute performance: 1.192327770022507
# SMA1 & SMA2: 20 65
# Absolute performance: 1.205650614443802
# SMA1 & SMA2: 20 70
# Absolute performance: 1.2625356626946695
# SMA1 & SMA2: 20 75
# Absolute performance: 1.2530081678667846
# SMA1 & SMA2: 20 80
# Absolute performance: 1.2328414010569797
# SMA1 & SMA2: 20 85
# Absolute performance: 1.2532434649952495
# SMA1 & SMA2: 20 90
# Absolute performance: 1.2213937725542472
# SMA1 & SMA2: 20 95
# Absolute performance: 1.134218467749613
# SMA1 & SMA2: 20 100
# Absolute performance: 1.2461063968993986
# SMA1 & SMA2: 20 105
# Absolute performance: 1.2262102832101198
# SMA1 & SMA2: 20 110
# Absolute performance: 1.1876628912118858
# SMA1 & SMA2: 20 115
# Absolute performance: 1.336278967572433
# SMA1 & SMA2: 20 120
# Absolute performance: 1.288970422753686
# SMA1 & SMA2: 20 125
# Absolute performance: 1.2290325276343415
# SMA1 & SMA2: 20 130
# Absolute performance: 1.2319792401199365
# SMA1 & SMA2: 20 135
# Absolute performance: 1.372167294308833
# SMA1 & SMA2: 20 140
# Absolute performance: 1.2854035809823152
# SMA1 & SMA2: 20 145
# Absolute performance: 1.2679843744816666
# SMA1 & SMA2: 20 150
# Absolute performance: 1.3618346771063077
# SMA1 & SMA2: 20 155
# Absolute performance: 1.3467342983811972
# SMA1 & SMA2: 20 160
# Absolute performance: 1.3735431420409288
# SMA1 & SMA2: 20 165
# Absolute performance: 1.4049033597494283
# SMA1 & SMA2: 20 170
# Absolute performance: 1.3776237770568458
# SMA1 & SMA2: 20 175
# Absolute performance: 1.32275613787449
# SMA1 & SMA2: 20 180
# Absolute performance: 1.327466443635222
# SMA1 & SMA2: 20 185
# Absolute performance: 1.3133289331172415
# SMA1 & SMA2: 20 190
# Absolute performance: 1.3180700388206847
# SMA1 & SMA2: 20 195
# Absolute performance: 1.3391383372918704
# SMA1 & SMA2: 25 50
# Absolute performance: 1.151733413140094
# SMA1 & SMA2: 25 55
# Absolute performance: 1.1294819533899854
# SMA1 & SMA2: 25 60
# Absolute performance: 1.1276577241054193
# SMA1 & SMA2: 25 65
# Absolute performance: 1.1542167580296725
# SMA1 & SMA2: 25 70
# Absolute performance: 1.1016153565372975
# SMA1 & SMA2: 25 75
# Absolute performance: 1.172457888109617
# SMA1 & SMA2: 25 80
# Absolute performance: 1.2599885305776677
# SMA1 & SMA2: 25 85
# Absolute performance: 1.2787404601158936
# SMA1 & SMA2: 25 90
# Absolute performance: 1.274071321200729
# SMA1 & SMA2: 25 95
# Absolute performance: 1.3500606864363307
# SMA1 & SMA2: 25 100
# Absolute performance: 1.3518074355198184
# SMA1 & SMA2: 25 105
# Absolute performance: 1.3136062650922817
# SMA1 & SMA2: 25 110
# Absolute performance: 1.364021144430542
# SMA1 & SMA2: 25 115
# Absolute performance: 1.2948419567278002
# SMA1 & SMA2: 25 120
# Absolute performance: 1.2527370965725153
# SMA1 & SMA2: 25 125
# Absolute performance: 1.2728666385390386
# SMA1 & SMA2: 25 130
# Absolute performance: 1.2775383060065788
# SMA1 & SMA2: 25 135
# Absolute performance: 1.329833311735776
# SMA1 & SMA2: 25 140
# Absolute performance: 1.3145246916585298
# SMA1 & SMA2: 25 145
# Absolute performance: 1.3774984624491597
# SMA1 & SMA2: 25 150
# Absolute performance: 1.4081977908087702
# SMA1 & SMA2: 25 155
# Absolute performance: 1.4463538164182987
# SMA1 & SMA2: 25 160
# Absolute performance: 1.4332564580865805
# SMA1 & SMA2: 25 165
# Absolute performance: 1.3625859180179165
# SMA1 & SMA2: 25 170
# Absolute performance: 1.3302660706052278
# SMA1 & SMA2: 25 175
# Absolute performance: 1.329513519682485
# SMA1 & SMA2: 25 180
# Absolute performance: 1.2896121272516239
# SMA1 & SMA2: 25 185
# Absolute performance: 1.3384755534638828
# SMA1 & SMA2: 25 190
# Absolute performance: 1.3246915395344
# SMA1 & SMA2: 25 195
# Absolute performance: 1.3143047014963014
# SMA1 & SMA2: 30 50
# Absolute performance: 1.2442928284812906
# SMA1 & SMA2: 30 55
# Absolute performance: 0.9929670990614513
# SMA1 & SMA2: 30 60
# Absolute performance: 1.1630383973246836
# SMA1 & SMA2: 30 65
# Absolute performance: 1.343902272759457
# SMA1 & SMA2: 30 70
# Absolute performance: 1.2802742756218763
# SMA1 & SMA2: 30 75
# Absolute performance: 1.2232261679847285
# SMA1 & SMA2: 30 80
# Absolute performance: 1.39666605136109
# SMA1 & SMA2: 30 85
# Absolute performance: 1.379162370262192
# SMA1 & SMA2: 30 90
# Absolute performance: 1.3594305599861205
# SMA1 & SMA2: 30 95
# Absolute performance: 1.4066386074108626
# SMA1 & SMA2: 30 100
# Absolute performance: 1.3733137910053677
# SMA1 & SMA2: 30 105
# Absolute performance: 1.3612526662271234
# SMA1 & SMA2: 30 110
# Absolute performance: 1.434511023620079
# SMA1 & SMA2: 30 115
# Absolute performance: 1.4484965747370029
# SMA1 & SMA2: 30 120
# Absolute performance: 1.4704761014970442
# SMA1 & SMA2: 30 125
# Absolute performance: 1.2718473055526318
# SMA1 & SMA2: 30 130
# Absolute performance: 1.2983614485023665
# SMA1 & SMA2: 30 135
# Absolute performance: 1.3575062520049739
# SMA1 & SMA2: 30 140
# Absolute performance: 1.393550384478726
# SMA1 & SMA2: 30 145
# Absolute performance: 1.4328388686841125
# SMA1 & SMA2: 30 150
# Absolute performance: 1.4325857822322539
# SMA1 & SMA2: 30 155
# Absolute performance: 1.3872739733433284
# SMA1 & SMA2: 30 160
# Absolute performance: 1.3503626429572442
# SMA1 & SMA2: 30 165
# Absolute performance: 1.2665777303971837
# SMA1 & SMA2: 30 170
# Absolute performance: 1.3230618647887473
# SMA1 & SMA2: 30 175
# Absolute performance: 1.3351248261866446
# SMA1 & SMA2: 30 180
# Absolute performance: 1.3230117084079338
# SMA1 & SMA2: 30 185
# Absolute performance: 1.3779701269119782
# SMA1 & SMA2: 30 190
# Absolute performance: 1.3401161680604177
# SMA1 & SMA2: 30 195
# Absolute performance: 1.4226970787697302
# SMA1 & SMA2: 35 50
# Absolute performance: 1.253337567135181
# SMA1 & SMA2: 35 55
# Absolute performance: 1.2563030376067195
# SMA1 & SMA2: 35 60
# Absolute performance: 1.348259422410736
# SMA1 & SMA2: 35 65
# Absolute performance: 1.3131999262424099
# SMA1 & SMA2: 35 70
# Absolute performance: 1.3951003813071103
# SMA1 & SMA2: 35 75
# Absolute performance: 1.229890677209278
# SMA1 & SMA2: 35 80
# Absolute performance: 1.1735395195497338
# SMA1 & SMA2: 35 85
# Absolute performance: 1.3074458332721657
# SMA1 & SMA2: 35 90
# Absolute performance: 1.4625725346839933
# SMA1 & SMA2: 35 95
# Absolute performance: 1.3972540109913687
# SMA1 & SMA2: 35 100
# Absolute performance: 1.3887533928143518
# SMA1 & SMA2: 35 105
# Absolute performance: 1.3745636616088062
# SMA1 & SMA2: 35 110
# Absolute performance: 1.3352303494464561
# SMA1 & SMA2: 35 115
# Absolute performance: 1.3015980489158725
# SMA1 & SMA2: 35 120
# Absolute performance: 1.3966949170665024
# SMA1 & SMA2: 35 125
# Absolute performance: 1.3023408474623417
# SMA1 & SMA2: 35 130
# Absolute performance: 1.318064539353728
# SMA1 & SMA2: 35 135
# Absolute performance: 1.3290954252685403
# SMA1 & SMA2: 35 140
# Absolute performance: 1.2991674337994465
# SMA1 & SMA2: 35 145
# Absolute performance: 1.2458994829077772
# SMA1 & SMA2: 35 150
# Absolute performance: 1.1809518706791144
# SMA1 & SMA2: 35 155
# Absolute performance: 1.2071428850292876
# SMA1 & SMA2: 35 160
# Absolute performance: 1.1993385171873432
# SMA1 & SMA2: 35 165
# Absolute performance: 1.3213295275673758
# SMA1 & SMA2: 35 170
# Absolute performance: 1.2928437747563388
# SMA1 & SMA2: 35 175
# Absolute performance: 1.288480922648009
# SMA1 & SMA2: 35 180
# Absolute performance: 1.3230033702345798
# SMA1 & SMA2: 35 185
# Absolute performance: 1.372136179910774
# SMA1 & SMA2: 35 190
# Absolute performance: 1.351563091388218
# SMA1 & SMA2: 35 195
# Absolute performance: 1.4375693497309685
# SMA1 & SMA2: 40 50
# Absolute performance: 1.494987175196267
# SMA1 & SMA2: 40 55
# Absolute performance: 1.5014504780084224
# SMA1 & SMA2: 40 60
# Absolute performance: 1.3317404540904834
# SMA1 & SMA2: 40 65
# Absolute performance: 1.3850550156057944
# SMA1 & SMA2: 40 70
# Absolute performance: 1.365434711943816
# SMA1 & SMA2: 40 75
# Absolute performance: 1.237912489779683
# SMA1 & SMA2: 40 80
# Absolute performance: 1.2989250001309949
# SMA1 & SMA2: 40 85
# Absolute performance: 1.405366419497091
# SMA1 & SMA2: 40 90
# Absolute performance: 1.4188247537607417
# SMA1 & SMA2: 40 95
# Absolute performance: 1.366224550439933
# SMA1 & SMA2: 40 100
# Absolute performance: 1.36724254247963
# SMA1 & SMA2: 40 105
# Absolute performance: 1.2994328704021139
# SMA1 & SMA2: 40 110
# Absolute performance: 1.260487828692943
# SMA1 & SMA2: 40 115
# Absolute performance: 1.2871588109044807
# SMA1 & SMA2: 40 120
# Absolute performance: 1.3739338396329543
# SMA1 & SMA2: 40 125
# Absolute performance: 1.3470234869127127
# SMA1 & SMA2: 40 130
# Absolute performance: 1.3424766360962845
# SMA1 & SMA2: 40 135
# Absolute performance: 1.334826603617901
# SMA1 & SMA2: 40 140
# Absolute performance: 1.2750242519190842
# SMA1 & SMA2: 40 145
# Absolute performance: 1.2433985499436577
# SMA1 & SMA2: 40 150
# Absolute performance: 1.3543788029391863
# SMA1 & SMA2: 40 155
# Absolute performance: 1.3162316934376146
# SMA1 & SMA2: 40 160
# Absolute performance: 1.38459608354416
# SMA1 & SMA2: 40 165
# Absolute performance: 1.4016793738942808
# SMA1 & SMA2: 40 170
# Absolute performance: 1.3898875715369843
# SMA1 & SMA2: 40 175
# Absolute performance: 1.3489886652069698
# SMA1 & SMA2: 40 180
# Absolute performance: 1.3116412904058525
# SMA1 & SMA2: 40 185
# Absolute performance: 1.3682938061974177
# SMA1 & SMA2: 40 190
# Absolute performance: 1.4205520500486293
# SMA1 & SMA2: 40 195
# Absolute performance: 1.3927706379107057
# SMA1 & SMA2: 45 50
# Absolute performance: 1.434724457011063
# SMA1 & SMA2: 45 55
# Absolute performance: 1.5034697051208936
# SMA1 & SMA2: 45 60
# Absolute performance: 1.4769128149239508
# SMA1 & SMA2: 45 65
# Absolute performance: 1.3929809836730824
# SMA1 & SMA2: 45 70
# Absolute performance: 1.4850161156848
# SMA1 & SMA2: 45 75
# Absolute performance: 1.4163180191979647
# SMA1 & SMA2: 45 80
# Absolute performance: 1.5258348081011157
# SMA1 & SMA2: 45 85
# Absolute performance: 1.4342356903629827
# SMA1 & SMA2: 45 90
# Absolute performance: 1.2901283253034055
# SMA1 & SMA2: 45 95
# Absolute performance: 1.2756494744579143
# SMA1 & SMA2: 45 100
# Absolute performance: 1.3126491033344967
# SMA1 & SMA2: 45 105
# Absolute performance: 1.2204238678705994
# SMA1 & SMA2: 45 110
# Absolute performance: 1.2684701948008898
# SMA1 & SMA2: 45 115
# Absolute performance: 1.3532460098443255
# SMA1 & SMA2: 45 120
# Absolute performance: 1.3727099836896248
# SMA1 & SMA2: 45 125
# Absolute performance: 1.3467135716555014
# SMA1 & SMA2: 45 130
# Absolute performance: 1.3255117420672649
# SMA1 & SMA2: 45 135
# Absolute performance: 1.382801913550834
# SMA1 & SMA2: 45 140
# Absolute performance: 1.3754529409358869
# SMA1 & SMA2: 45 145
# Absolute performance: 1.3498895565844653
# SMA1 & SMA2: 45 150
# Absolute performance: 1.3369166052373929
# SMA1 & SMA2: 45 155
# Absolute performance: 1.3924772597715613
# SMA1 & SMA2: 45 160
# Absolute performance: 1.3827577649228313
# SMA1 & SMA2: 45 165
# Absolute performance: 1.4673467433849012
# SMA1 & SMA2: 45 170
# Absolute performance: 1.439823600750635
# SMA1 & SMA2: 45 175
# Absolute performance: 1.4019417947758597
# SMA1 & SMA2: 45 180
# Absolute performance: 1.3429604719821178
# SMA1 & SMA2: 45 185
# Absolute performance: 1.4574711912399003
# SMA1 & SMA2: 45 190
# Absolute performance: 1.4485174904345348
# SMA1 & SMA2: 45 195
# Absolute performance: 1.3991442752611665
# SMA1 & SMA2: 45 80
# Absolute performance: 1.5258348081011157
# CPU times: user 377 ms, sys: 0 ns, total: 377 ms
# Wall time: 389 ms
# (array([45., 80.]), np.float64(1.53))

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 45, 80, '2015-1-1', '2019-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 45 80
# Absolute performance: 1.0513784589098338
# (np.float64(1.05), np.float64(0.15))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 20, 50, '2020-1-1', '2023-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 20 50
# Absolute performance: 1.1452735255668045
# (np.float64(1.15), np.float64(-0.19))

# %%
# %%time
smabt.optimize_parameters((10,50,5), (50,200,5))
# Out:
# SMA1 & SMA2: 10 50
# Absolute performance: 1.2061329838265908
# SMA1 & SMA2: 10 55
# Absolute performance: 1.254985539482033
# SMA1 & SMA2: 10 60
# Absolute performance: 1.2882585591237716
# SMA1 & SMA2: 10 65
# Absolute performance: 1.4888512861631553
# SMA1 & SMA2: 10 70
# Absolute performance: 1.4602801650133541
# SMA1 & SMA2: 10 75
# Absolute performance: 1.414577721839376
# SMA1 & SMA2: 10 80
# Absolute performance: 1.3981244674557631
# SMA1 & SMA2: 10 85
# Absolute performance: 1.4231617842892972
# SMA1 & SMA2: 10 90
# Absolute performance: 1.4452806197317127
# SMA1 & SMA2: 10 95
# Absolute performance: 1.3299200052047797
# SMA1 & SMA2: 10 100
# Absolute performance: 1.4009463042207229
# SMA1 & SMA2: 10 105
# Absolute performance: 1.4994514378351835
# SMA1 & SMA2: 10 110
# Absolute performance: 1.5599138684310045
# SMA1 & SMA2: 10 115
# Absolute performance: 1.5587938952246592
# SMA1 & SMA2: 10 120
# Absolute performance: 1.5575901680726714
# SMA1 & SMA2: 10 125
# Absolute performance: 1.4332441477998414
# SMA1 & SMA2: 10 130
# Absolute performance: 1.4469611702842877
# SMA1 & SMA2: 10 135
# Absolute performance: 1.4131775701571405
# SMA1 & SMA2: 10 140
# Absolute performance: 1.380467514449346
# SMA1 & SMA2: 10 145
# Absolute performance: 1.32655078889218
# SMA1 & SMA2: 10 150
# Absolute performance: 1.3342390300604698
# SMA1 & SMA2: 10 155
# Absolute performance: 1.3518693216665076
# SMA1 & SMA2: 10 160
# Absolute performance: 1.351144668227411
# SMA1 & SMA2: 10 165
# Absolute performance: 1.316268589486245
# SMA1 & SMA2: 10 170
# Absolute performance: 1.3525089056289683
# SMA1 & SMA2: 10 175
# Absolute performance: 1.3414370026104985
# SMA1 & SMA2: 10 180
# Absolute performance: 1.362706383224879
# SMA1 & SMA2: 10 185
# Absolute performance: 1.2887610340741564
# SMA1 & SMA2: 10 190
# Absolute performance: 1.1611026979552288
# SMA1 & SMA2: 10 195
# Absolute performance: 1.2140980734643787
# SMA1 & SMA2: 15 50
# Absolute performance: 1.265793978475075
# SMA1 & SMA2: 15 55
# Absolute performance: 1.2116970981263089
# SMA1 & SMA2: 15 60
# Absolute performance: 1.2796041682049115
# SMA1 & SMA2: 15 65
# Absolute performance: 1.3336086617016103
# SMA1 & SMA2: 15 70
# Absolute performance: 1.4600189629809663
# SMA1 & SMA2: 15 75
# Absolute performance: 1.3922867734732718
# SMA1 & SMA2: 15 80
# Absolute performance: 1.3955975889370726
# SMA1 & SMA2: 15 85
# Absolute performance: 1.378034780821906
# SMA1 & SMA2: 15 90
# Absolute performance: 1.3176057014595088
# SMA1 & SMA2: 15 95
# Absolute performance: 1.3956340160167562
# SMA1 & SMA2: 15 100
# Absolute performance: 1.5065793774843503
# SMA1 & SMA2: 15 105
# Absolute performance: 1.4833691914553275
# SMA1 & SMA2: 15 110
# Absolute performance: 1.5537072350410268
# SMA1 & SMA2: 15 115
# Absolute performance: 1.5024269913334813
# SMA1 & SMA2: 15 120
# Absolute performance: 1.4407883555897962
# SMA1 & SMA2: 15 125
# Absolute performance: 1.394125217989759
# SMA1 & SMA2: 15 130
# Absolute performance: 1.4733689889439943
# SMA1 & SMA2: 15 135
# Absolute performance: 1.391958402110401
# SMA1 & SMA2: 15 140
# Absolute performance: 1.3994474503228167
# SMA1 & SMA2: 15 145
# Absolute performance: 1.3866493705702616
# SMA1 & SMA2: 15 150
# Absolute performance: 1.348992170464685
# SMA1 & SMA2: 15 155
# Absolute performance: 1.3581902980444605
# SMA1 & SMA2: 15 160
# Absolute performance: 1.3481974865701243
# SMA1 & SMA2: 15 165
# Absolute performance: 1.316043144511862
# SMA1 & SMA2: 15 170
# Absolute performance: 1.2840645327355193
# SMA1 & SMA2: 15 175
# Absolute performance: 1.2821682555886103
# SMA1 & SMA2: 15 180
# Absolute performance: 1.3207169272370238
# SMA1 & SMA2: 15 185
# Absolute performance: 1.2715483253135453
# SMA1 & SMA2: 15 190
# Absolute performance: 1.1568463693636164
# SMA1 & SMA2: 15 195
# Absolute performance: 1.1703542253145713
# SMA1 & SMA2: 20 50
# Absolute performance: 1.1452735255668045
# SMA1 & SMA2: 20 55
# Absolute performance: 1.1687703725556786
# SMA1 & SMA2: 20 60
# Absolute performance: 1.312340952804705
# SMA1 & SMA2: 20 65
# Absolute performance: 1.4021355556741593
# SMA1 & SMA2: 20 70
# Absolute performance: 1.3277760233273161
# SMA1 & SMA2: 20 75
# Absolute performance: 1.3163659001439991
# SMA1 & SMA2: 20 80
# Absolute performance: 1.4000426805690724
# SMA1 & SMA2: 20 85
# Absolute performance: 1.3950642343479058
# SMA1 & SMA2: 20 90
# Absolute performance: 1.4335592034070959
# SMA1 & SMA2: 20 95
# Absolute performance: 1.3588226528653862
# SMA1 & SMA2: 20 100
# Absolute performance: 1.393503589747527
# SMA1 & SMA2: 20 105
# Absolute performance: 1.4161058178138262
# SMA1 & SMA2: 20 110
# Absolute performance: 1.3617775750042647
# SMA1 & SMA2: 20 115
# Absolute performance: 1.322839585870305
# SMA1 & SMA2: 20 120
# Absolute performance: 1.3350101532556737
# SMA1 & SMA2: 20 125
# Absolute performance: 1.4153159712021064
# SMA1 & SMA2: 20 130
# Absolute performance: 1.45298171382612
# SMA1 & SMA2: 20 135
# Absolute performance: 1.4624292510131385
# SMA1 & SMA2: 20 140
# Absolute performance: 1.4121758924426637
# SMA1 & SMA2: 20 145
# Absolute performance: 1.3467332449919356
# SMA1 & SMA2: 20 150
# Absolute performance: 1.3269064261080359
# SMA1 & SMA2: 20 155
# Absolute performance: 1.3500595661303763
# SMA1 & SMA2: 20 160
# Absolute performance: 1.3080657302627234
# SMA1 & SMA2: 20 165
# Absolute performance: 1.334787408234722
# SMA1 & SMA2: 20 170
# Absolute performance: 1.2901428604503116
# SMA1 & SMA2: 20 175
# Absolute performance: 1.2702796440708477
# SMA1 & SMA2: 20 180
# Absolute performance: 1.1656760292479786
# SMA1 & SMA2: 20 185
# Absolute performance: 1.183293185451364
# SMA1 & SMA2: 20 190
# Absolute performance: 1.1774117704650888
# SMA1 & SMA2: 20 195
# Absolute performance: 1.180018386397842
# SMA1 & SMA2: 25 50
# Absolute performance: 1.1522645636836817
# SMA1 & SMA2: 25 55
# Absolute performance: 1.2628453973975693
# SMA1 & SMA2: 25 60
# Absolute performance: 1.3192129663057142
# SMA1 & SMA2: 25 65
# Absolute performance: 1.283383018992412
# SMA1 & SMA2: 25 70
# Absolute performance: 1.4351913847593283
# SMA1 & SMA2: 25 75
# Absolute performance: 1.4389011670090377
# SMA1 & SMA2: 25 80
# Absolute performance: 1.3358315102473672
# SMA1 & SMA2: 25 85
# Absolute performance: 1.330028019203612
# SMA1 & SMA2: 25 90
# Absolute performance: 1.367869630425256
# SMA1 & SMA2: 25 95
# Absolute performance: 1.384421579459126
# SMA1 & SMA2: 25 100
# Absolute performance: 1.4064542632660966
# SMA1 & SMA2: 25 105
# Absolute performance: 1.3849193935778097
# SMA1 & SMA2: 25 110
# Absolute performance: 1.4041577163513586
# SMA1 & SMA2: 25 115
# Absolute performance: 1.4051712540127346
# SMA1 & SMA2: 25 120
# Absolute performance: 1.4254126334282933
# SMA1 & SMA2: 25 125
# Absolute performance: 1.404846998792581
# SMA1 & SMA2: 25 130
# Absolute performance: 1.4484121342868745
# SMA1 & SMA2: 25 135
# Absolute performance: 1.4136503341858715
# SMA1 & SMA2: 25 140
# Absolute performance: 1.40201011900222
# SMA1 & SMA2: 25 145
# Absolute performance: 1.3086258574791785
# SMA1 & SMA2: 25 150
# Absolute performance: 1.2775645744155328
# SMA1 & SMA2: 25 155
# Absolute performance: 1.2538845277238677
# SMA1 & SMA2: 25 160
# Absolute performance: 1.2954415524624754
# SMA1 & SMA2: 25 165
# Absolute performance: 1.2409204101250042
# SMA1 & SMA2: 25 170
# Absolute performance: 1.1618432466512332
# SMA1 & SMA2: 25 175
# Absolute performance: 1.1768524465511299
# SMA1 & SMA2: 25 180
# Absolute performance: 1.1841056682995097
# SMA1 & SMA2: 25 185
# Absolute performance: 1.1873136865886875
# SMA1 & SMA2: 25 190
# Absolute performance: 1.2028326676052201
# SMA1 & SMA2: 25 195
# Absolute performance: 1.2014066340885055
# SMA1 & SMA2: 30 50
# Absolute performance: 1.2488809600030828
# SMA1 & SMA2: 30 55
# Absolute performance: 1.2809400678592084
# SMA1 & SMA2: 30 60
# Absolute performance: 1.3299880897151803
# SMA1 & SMA2: 30 65
# Absolute performance: 1.3920167466174032
# SMA1 & SMA2: 30 70
# Absolute performance: 1.4545806490950404
# SMA1 & SMA2: 30 75
# Absolute performance: 1.3494496957820636
# SMA1 & SMA2: 30 80
# Absolute performance: 1.4420025242107437
# SMA1 & SMA2: 30 85
# Absolute performance: 1.428176160539025
# SMA1 & SMA2: 30 90
# Absolute performance: 1.3744985540655166
# SMA1 & SMA2: 30 95
# Absolute performance: 1.4278868629614654
# SMA1 & SMA2: 30 100
# Absolute performance: 1.3202022449176003
# SMA1 & SMA2: 30 105
# Absolute performance: 1.3761384421273049
# SMA1 & SMA2: 30 110
# Absolute performance: 1.4536363103075398
# SMA1 & SMA2: 30 115
# Absolute performance: 1.4660652525570228
# SMA1 & SMA2: 30 120
# Absolute performance: 1.402524295830548
# SMA1 & SMA2: 30 125
# Absolute performance: 1.3625471782232266
# SMA1 & SMA2: 30 130
# Absolute performance: 1.3678055280193038
# SMA1 & SMA2: 30 135
# Absolute performance: 1.341326146195567
# SMA1 & SMA2: 30 140
# Absolute performance: 1.3212250469353242
# SMA1 & SMA2: 30 145
# Absolute performance: 1.3029347661564499
# SMA1 & SMA2: 30 150
# Absolute performance: 1.2691822722850372
# SMA1 & SMA2: 30 155
# Absolute performance: 1.1567719871687079
# SMA1 & SMA2: 30 160
# Absolute performance: 1.1558137247435418
# SMA1 & SMA2: 30 165
# Absolute performance: 1.1724125842052127
# SMA1 & SMA2: 30 170
# Absolute performance: 1.1838080999945866
# SMA1 & SMA2: 30 175
# Absolute performance: 1.186774937191109
# SMA1 & SMA2: 30 180
# Absolute performance: 1.1550179858917986
# SMA1 & SMA2: 30 185
# Absolute performance: 1.1669798625570855
# SMA1 & SMA2: 30 190
# Absolute performance: 1.1517618278635138
# SMA1 & SMA2: 30 195
# Absolute performance: 1.1190609808569667
# SMA1 & SMA2: 35 50
# Absolute performance: 1.3055202273749238
# SMA1 & SMA2: 35 55
# Absolute performance: 1.3544374311381926
# SMA1 & SMA2: 35 60
# Absolute performance: 1.3141060081951654
# SMA1 & SMA2: 35 65
# Absolute performance: 1.2659102391142074
# SMA1 & SMA2: 35 70
# Absolute performance: 1.3228001816608124
# SMA1 & SMA2: 35 75
# Absolute performance: 1.3711433485445272
# SMA1 & SMA2: 35 80
# Absolute performance: 1.3933156901003299
# SMA1 & SMA2: 35 85
# Absolute performance: 1.424428649272941
# SMA1 & SMA2: 35 90
# Absolute performance: 1.467736504135924
# SMA1 & SMA2: 35 95
# Absolute performance: 1.4788137816290121
# SMA1 & SMA2: 35 100
# Absolute performance: 1.404017468015062
# SMA1 & SMA2: 35 105
# Absolute performance: 1.3649108301103732
# SMA1 & SMA2: 35 110
# Absolute performance: 1.4722198820395584
# SMA1 & SMA2: 35 115
# Absolute performance: 1.4171352449544314
# SMA1 & SMA2: 35 120
# Absolute performance: 1.397839301735136
# SMA1 & SMA2: 35 125
# Absolute performance: 1.3548746932242524
# SMA1 & SMA2: 35 130
# Absolute performance: 1.3507573331140947
# SMA1 & SMA2: 35 135
# Absolute performance: 1.217041394336977
# SMA1 & SMA2: 35 140
# Absolute performance: 1.2091669040310575
# SMA1 & SMA2: 35 145
# Absolute performance: 1.2087399608231153
# SMA1 & SMA2: 35 150
# Absolute performance: 1.1563014040631816
# SMA1 & SMA2: 35 155
# Absolute performance: 1.153734404812808
# SMA1 & SMA2: 35 160
# Absolute performance: 1.1839842600768118
# SMA1 & SMA2: 35 165
# Absolute performance: 1.1704750794287093
# SMA1 & SMA2: 35 170
# Absolute performance: 1.170785569999244
# SMA1 & SMA2: 35 175
# Absolute performance: 1.1820846002663115
# SMA1 & SMA2: 35 180
# Absolute performance: 1.144295938858226
# SMA1 & SMA2: 35 185
# Absolute performance: 1.1293773837591434
# SMA1 & SMA2: 35 190
# Absolute performance: 1.1113549741239552
# SMA1 & SMA2: 35 195
# Absolute performance: 1.118270337848876
# SMA1 & SMA2: 40 50
# Absolute performance: 1.1585870526525168
# SMA1 & SMA2: 40 55
# Absolute performance: 1.1696973881533723
# SMA1 & SMA2: 40 60
# Absolute performance: 1.255044669622529
# SMA1 & SMA2: 40 65
# Absolute performance: 1.2866366828650082
# SMA1 & SMA2: 40 70
# Absolute performance: 1.2625741209459402
# SMA1 & SMA2: 40 75
# Absolute performance: 1.3095127388685572
# SMA1 & SMA2: 40 80
# Absolute performance: 1.4175894356391403
# SMA1 & SMA2: 40 85
# Absolute performance: 1.4208411263243155
# SMA1 & SMA2: 40 90
# Absolute performance: 1.3936564938166163
# SMA1 & SMA2: 40 95
# Absolute performance: 1.4302302085842056
# SMA1 & SMA2: 40 100
# Absolute performance: 1.4256769888319984
# SMA1 & SMA2: 40 105
# Absolute performance: 1.3879983786770773
# SMA1 & SMA2: 40 110
# Absolute performance: 1.2964974356495063
# SMA1 & SMA2: 40 115
# Absolute performance: 1.2692553526710655
# SMA1 & SMA2: 40 120
# Absolute performance: 1.2643628049061495
# SMA1 & SMA2: 40 125
# Absolute performance: 1.2448314495341886
# SMA1 & SMA2: 40 130
# Absolute performance: 1.218177595050964
# SMA1 & SMA2: 40 135
# Absolute performance: 1.2190142804565067
# SMA1 & SMA2: 40 140
# Absolute performance: 1.2132001944077764
# SMA1 & SMA2: 40 145
# Absolute performance: 1.1837840892715095
# SMA1 & SMA2: 40 150
# Absolute performance: 1.1458235307628901
# SMA1 & SMA2: 40 155
# Absolute performance: 1.183416909045402
# SMA1 & SMA2: 40 160
# Absolute performance: 1.1752515356490387
# SMA1 & SMA2: 40 165
# Absolute performance: 1.1112351671807374
# SMA1 & SMA2: 40 170
# Absolute performance: 1.1151597201342338
# SMA1 & SMA2: 40 175
# Absolute performance: 1.0948237390401396
# SMA1 & SMA2: 40 180
# Absolute performance: 1.129489997220723
# SMA1 & SMA2: 40 185
# Absolute performance: 1.1159526462168572
# SMA1 & SMA2: 40 190
# Absolute performance: 1.1377905473464855
# SMA1 & SMA2: 40 195
# Absolute performance: 1.148512466597436
# SMA1 & SMA2: 45 50
# Absolute performance: 1.1338671739868007
# SMA1 & SMA2: 45 55
# Absolute performance: 1.1514105460038595
# SMA1 & SMA2: 45 60
# Absolute performance: 1.315925772371771
# SMA1 & SMA2: 45 65
# Absolute performance: 1.2938382101714745
# SMA1 & SMA2: 45 70
# Absolute performance: 1.3087418101218473
# SMA1 & SMA2: 45 75
# Absolute performance: 1.3398656398441193
# SMA1 & SMA2: 45 80
# Absolute performance: 1.4430339282685831
# SMA1 & SMA2: 45 85
# Absolute performance: 1.4065881273639986
# SMA1 & SMA2: 45 90
# Absolute performance: 1.4162961079056038
# SMA1 & SMA2: 45 95
# Absolute performance: 1.3304907543014306
# SMA1 & SMA2: 45 100
# Absolute performance: 1.2938392940391854
# SMA1 & SMA2: 45 105
# Absolute performance: 1.315036110082425
# SMA1 & SMA2: 45 110
# Absolute performance: 1.3212989350562574
# SMA1 & SMA2: 45 115
# Absolute performance: 1.3101951521276753
# SMA1 & SMA2: 45 120
# Absolute performance: 1.2656464180543296
# SMA1 & SMA2: 45 125
# Absolute performance: 1.2112461231210658
# SMA1 & SMA2: 45 130
# Absolute performance: 1.240512131127741
# SMA1 & SMA2: 45 135
# Absolute performance: 1.2166395962633825
# SMA1 & SMA2: 45 140
# Absolute performance: 1.1723205759993767
# SMA1 & SMA2: 45 145
# Absolute performance: 1.1366884541962037
# SMA1 & SMA2: 45 150
# Absolute performance: 1.0992281076981647
# SMA1 & SMA2: 45 155
# Absolute performance: 1.1055065983524985
# SMA1 & SMA2: 45 160
# Absolute performance: 1.1091428855824255
# SMA1 & SMA2: 45 165
# Absolute performance: 1.1401266091958373
# SMA1 & SMA2: 45 170
# Absolute performance: 1.1626907495601377
# SMA1 & SMA2: 45 175
# Absolute performance: 1.1658261803042826
# SMA1 & SMA2: 45 180
# Absolute performance: 1.126923525687262
# SMA1 & SMA2: 45 185
# Absolute performance: 1.1228028647295731
# SMA1 & SMA2: 45 190
# Absolute performance: 1.1006235143594352
# SMA1 & SMA2: 45 195
# Absolute performance: 1.0891016752658689
# SMA1 & SMA2: 10 110
# Absolute performance: 1.5599138684310045
# CPU times: user 385 ms, sys: 0 ns, total: 385 ms
# Wall time: 396 ms
# (array([ 10., 110.]), np.float64(1.56))

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 10, 110, '2024-1-1', '2026-7-7','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 10 110
# Absolute performance: 1.037863372109197
# (np.float64(1.04), np.float64(0.01))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',15, 60, '2020-1-1', '2026-7-9','H4')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 15 60
# Absolute performance: 0.9734463093657132
# (np.float64(0.97), np.float64(-0.51))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((10,20,5), (40,80,5))
# Out:
# SMA1 & SMA2: 10 40
# Absolute performance: 0.9920416015088414
# SMA1 & SMA2: 10 45
# Absolute performance: 0.9887861700796327
# SMA1 & SMA2: 10 50
# Absolute performance: 0.9767330597916717
# SMA1 & SMA2: 10 55
# Absolute performance: 0.9696719384487154
# SMA1 & SMA2: 10 60
# Absolute performance: 0.961655430061199
# SMA1 & SMA2: 10 65
# Absolute performance: 0.9625615893489324
# SMA1 & SMA2: 10 70
# Absolute performance: 0.9651760673628396
# SMA1 & SMA2: 10 75
# Absolute performance: 0.9874714576276062
# SMA1 & SMA2: 15 40
# Absolute performance: 0.9860616908185968
# SMA1 & SMA2: 15 45
# Absolute performance: 1.0068467888099524
# SMA1 & SMA2: 15 50
# Absolute performance: 0.9839270383230738
# SMA1 & SMA2: 15 55
# Absolute performance: 0.9723451663979492
# SMA1 & SMA2: 15 60
# Absolute performance: 0.9739997223653889
# SMA1 & SMA2: 15 65
# Absolute performance: 0.9793526643913864
# SMA1 & SMA2: 15 70
# Absolute performance: 0.9811494821404924
# SMA1 & SMA2: 15 75
# Absolute performance: 0.953920293952883
# SMA1 & SMA2: 15 45
# Absolute performance: 1.0068467888099524
# CPU times: user 54.3 ms, sys: 76 μs, total: 54.4 ms
# Wall time: 53.1 ms
# (array([15., 45.]), np.float64(1.01))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',10, 40, '2026-1-1', '2026-7-9','H1')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 10 40
# Absolute performance: 0.9920416015088414
# (np.float64(0.99), np.float64(-0.05))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((5,15,5), (20,50,5))
# Out:
# SMA1 & SMA2: 5 20
# Absolute performance: 1.0584267283130377
# SMA1 & SMA2: 5 25
# Absolute performance: 1.0523806319430484
# SMA1 & SMA2: 5 30
# Absolute performance: 1.0460865927694636
# SMA1 & SMA2: 5 35
# Absolute performance: 1.0218108802477197
# SMA1 & SMA2: 5 40
# Absolute performance: 1.0331404190970979
# SMA1 & SMA2: 5 45
# Absolute performance: 1.0387534479339413
# SMA1 & SMA2: 10 20
# Absolute performance: 1.049814373927303
# SMA1 & SMA2: 10 25
# Absolute performance: 1.025142093430571
# SMA1 & SMA2: 10 30
# Absolute performance: 1.0311663229683208
# SMA1 & SMA2: 10 35
# Absolute performance: 1.0396398921646108
# SMA1 & SMA2: 10 40
# Absolute performance: 0.9920416015088414
# SMA1 & SMA2: 10 45
# Absolute performance: 0.9887861700796327
# SMA1 & SMA2: 5 20
# Absolute performance: 1.0584267283130377
# CPU times: user 38.7 ms, sys: 0 ns, total: 38.7 ms
# Wall time: 38.8 ms
# (array([ 5., 20.]), np.float64(1.06))

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',5, 20, '2026-1-1', '2026-7-9','H1')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 5 20
# Absolute performance: 1.0584267283130377
# (np.float64(1.06), np.float64(0.02))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',5, 20, '2026-4-1', '2026-7-9','M15')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 5 20
# Absolute performance: 0.9516565223746404
# (np.float64(0.95), np.float64(-0.07))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((3,10,2), (10,30,5))
# Out:
# SMA1 & SMA2: 3 10
# Absolute performance: 0.9850662500276856
# SMA1 & SMA2: 3 15
# Absolute performance: 0.9402086628888093
# SMA1 & SMA2: 3 20
# Absolute performance: 0.9249579165177965
# SMA1 & SMA2: 3 25
# Absolute performance: 0.9591013249387992
# SMA1 & SMA2: 5 10
# Absolute performance: 0.9827080019960699
# SMA1 & SMA2: 5 15
# Absolute performance: 0.9737182729615513
# SMA1 & SMA2: 5 20
# Absolute performance: 0.9516565223746404
# SMA1 & SMA2: 5 25
# Absolute performance: 0.9417400227693613
# SMA1 & SMA2: 7 10
# Absolute performance: 0.9774374196538391
# SMA1 & SMA2: 7 15
# Absolute performance: 0.9593741865353322
# SMA1 & SMA2: 7 20
# Absolute performance: 0.9366348541540784
# SMA1 & SMA2: 7 25
# Absolute performance: 0.9740225080256956
# SMA1 & SMA2: 9 10
# Absolute performance: 0.9489932400296778
# SMA1 & SMA2: 9 15
# Absolute performance: 0.952489824341296
# SMA1 & SMA2: 9 20
# Absolute performance: 0.9470220617898515
# SMA1 & SMA2: 9 25
# Absolute performance: 0.9493730807257292
# SMA1 & SMA2: 3 10
# Absolute performance: 0.9850662500276856
# CPU times: user 51.8 ms, sys: 14 μs, total: 51.8 ms
# Wall time: 51.5 ms
# (array([ 3., 10.]), np.float64(0.99))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',3, 15, '2026-4-1', '2026-7-9','M5')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 3 15
# Absolute performance: 0.9902946771821659
# (np.float64(0.99), np.float64(-0.03))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((2,5,1), (5,20,5))
# Out:
# SMA1 & SMA2: 2 5
# Absolute performance: 1.0220958954635975
# SMA1 & SMA2: 2 10
# Absolute performance: 0.9449407148913189
# SMA1 & SMA2: 2 15
# Absolute performance: 0.9622228310731161
# SMA1 & SMA2: 3 5
# Absolute performance: 1.0393402869863244
# SMA1 & SMA2: 3 10
# Absolute performance: 0.9760457845077817
# SMA1 & SMA2: 3 15
# Absolute performance: 0.9902946771821659
# SMA1 & SMA2: 4 5
# Absolute performance: 1.0143441535482784
# SMA1 & SMA2: 4 10
# Absolute performance: 1.0060921157737603
# SMA1 & SMA2: 4 15
# Absolute performance: 0.9939248889923318
# SMA1 & SMA2: 3 5
# Absolute performance: 1.0393402869863244
# CPU times: user 44.2 ms, sys: 0 ns, total: 44.2 ms
# Wall time: 44.5 ms
# (array([3., 5.]), np.float64(1.04))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',2 , 6, '2026-4-1', '2026-7-9','M1')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 2 6
# Absolute performance: 0.8909981872210282
# (np.float64(0.89), np.float64(-0.13))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((1,3,1), (3,10,1))
# Out:
# SMA1 & SMA2: 1 3
# Absolute performance: 0.8380026116919203
# SMA1 & SMA2: 1 4
# Absolute performance: 0.8403478874661717
# SMA1 & SMA2: 1 5
# Absolute performance: 0.8318875243748943
# SMA1 & SMA2: 1 6
# Absolute performance: 0.8182464987055277
# SMA1 & SMA2: 1 7
# Absolute performance: 0.8396120833465528
# SMA1 & SMA2: 1 8
# Absolute performance: 0.8525811424998072
# SMA1 & SMA2: 1 9
# Absolute performance: 0.8655662920021073
# SMA1 & SMA2: 2 3
# Absolute performance: 0.9064915702997822
# SMA1 & SMA2: 2 4
# Absolute performance: 0.9171826438262933
# SMA1 & SMA2: 2 5
# Absolute performance: 0.8948864748790606
# SMA1 & SMA2: 2 6
# Absolute performance: 0.8909981872210282
# SMA1 & SMA2: 2 7
# Absolute performance: 0.9008077444570013
# SMA1 & SMA2: 2 8
# Absolute performance: 0.9081113867547338
# SMA1 & SMA2: 2 9
# Absolute performance: 0.9192240299922332
# SMA1 & SMA2: 2 4
# Absolute performance: 0.9171826438262933
# CPU times: user 139 ms, sys: 19.3 ms, total: 158 ms
# Wall time: 164 ms
# (array([2., 4.]), np.float64(0.92))

# %%
smabt.plot_results()
