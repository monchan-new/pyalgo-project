# %%
import SMAVectorBacktester as SMA

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 20, 50, '2008-11-1', '2009-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 20 50
# Absolute performance: 1.0320683388543161
# (np.float64(1.03), np.float64(0.01))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((10,50,5), (50,200,5))
# Out:
# SMA1 & SMA2: 10 50
# Absolute performance: 0.8918164080121276
# SMA1 & SMA2: 10 55
# Absolute performance: 0.915272726962769
# SMA1 & SMA2: 10 60
# Absolute performance: 0.9571080489000763
# SMA1 & SMA2: 10 65
# Absolute performance: 0.9365241227800456
# SMA1 & SMA2: 10 70
# Absolute performance: 0.9902416395886363
# SMA1 & SMA2: 10 75
# Absolute performance: 0.9892827506665386
# SMA1 & SMA2: 10 80
# Absolute performance: 0.9904239446854751
# SMA1 & SMA2: 10 85
# Absolute performance: 0.9388071244169961
# SMA1 & SMA2: 10 90
# Absolute performance: 0.9267499704374674
# SMA1 & SMA2: 10 95
# Absolute performance: 0.9832069123192906
# SMA1 & SMA2: 10 100
# Absolute performance: 0.9686758753009126
# SMA1 & SMA2: 10 105
# Absolute performance: 0.9433075079061749
# SMA1 & SMA2: 10 110
# Absolute performance: 0.9277813023132163
# SMA1 & SMA2: 10 115
# Absolute performance: 0.9780314078626308
# SMA1 & SMA2: 10 120
# Absolute performance: 0.9651503761978469
# SMA1 & SMA2: 10 125
# ...

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 15, 60, '2008-10-20', '2009-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 15 60
# Absolute performance: 1.046361354419929
# (np.float64(1.05), np.float64(0.02))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 20, 50, '2018-10-20', '2019-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 20 50
# Absolute performance: 0.9622026464802724
# (np.float64(0.96), np.float64(-0.02))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((10,50,5), (50,200,5))
# Out:
# SMA1 & SMA2: 10 50
# Absolute performance: 0.9638906351459854
# SMA1 & SMA2: 10 55
# Absolute performance: 0.9996292295031318
# SMA1 & SMA2: 10 60
# Absolute performance: 0.9948595925397161
# SMA1 & SMA2: 10 65
# Absolute performance: 1.0030854881611821
# SMA1 & SMA2: 10 70
# Absolute performance: 0.9781394636308431
# SMA1 & SMA2: 10 75
# Absolute performance: 0.9858948669724746
# SMA1 & SMA2: 10 80
# Absolute performance: 0.9900528916875646
# SMA1 & SMA2: 10 85
# Absolute performance: 0.9769163763351755
# SMA1 & SMA2: 10 90
# Absolute performance: 0.960200557585091
# SMA1 & SMA2: 10 95
# Absolute performance: 0.9718647762329178
# SMA1 & SMA2: 10 100
# Absolute performance: 0.981708766776393
# SMA1 & SMA2: 10 105
# Absolute performance: 0.9489946150189504
# SMA1 & SMA2: 10 110
# Absolute performance: 0.9667487257493651
# SMA1 & SMA2: 10 115
# Absolute performance: 0.9947287999028983
# SMA1 & SMA2: 10 120
# Absolute performance: 0.989037436911307
# SMA1 & SMA2: 10 125
# ...

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 25, 95, '2018-8-20', '2019-12-31','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 25 95
# Absolute performance: 1.0104327390705363
# (np.float64(1.01), np.float64(0.03))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 20, 50, '2025-10-20', '2026-7-7','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 20 50
# Absolute performance: 0.9333306443426956
# (np.float64(0.93), np.float64(-0.11))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((10,50,5), (50,180,5))
# Out:
# SMA1 & SMA2: 10 50
# Absolute performance: 0.9513066193575861
# SMA1 & SMA2: 10 55
# Absolute performance: 0.9475357135877421
# SMA1 & SMA2: 10 60
# Absolute performance: 0.9363729699651735
# SMA1 & SMA2: 10 65
# Absolute performance: 0.9711085304509
# SMA1 & SMA2: 10 70
# Absolute performance: 1.0124257429590493
# SMA1 & SMA2: 10 75
# Absolute performance: 1.0070434621509428
# SMA1 & SMA2: 10 80
# Absolute performance: 1.0034140655466472
# SMA1 & SMA2: 10 85
# Absolute performance: 0.9848398188811033
# SMA1 & SMA2: 10 90
# Absolute performance: 1.0005285751373931
# SMA1 & SMA2: 10 95
# Absolute performance: 1.01307464757524
# SMA1 & SMA2: 10 100
# Absolute performance: 1.0142717158794996
# SMA1 & SMA2: 10 105
# Absolute performance: 1.008313666932132
# SMA1 & SMA2: 10 110
# Absolute performance: 1.0151945280466843
# SMA1 & SMA2: 10 115
# Absolute performance: 1.0150730045465657
# SMA1 & SMA2: 10 120
# Absolute performance: 1.0157133011716049
# SMA1 & SMA2: 10 125
# ...

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 15, 70, '2025-9-20', '2026-7-7','D')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 15 70
# Absolute performance: 1.0276387093458466
# (np.float64(1.03), np.float64(-0.01))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',15, 60, '2020-1-1', '2026-7-9','H4')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 15 60
# Absolute performance: 0.9734463093657132
# (np.float64(0.97), np.float64(-0.51))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((10,20,5), (40,80,5))
# Out:
# SMA1 & SMA2: 10 40
# Absolute performance: 0.9920416015088414
# SMA1 & SMA2: 10 45
# Absolute performance: 0.9887861700796327
# SMA1 & SMA2: 10 50
# Absolute performance: 0.9767330597916717
# SMA1 & SMA2: 10 55
# Absolute performance: 0.9696719384487154
# SMA1 & SMA2: 10 60
# Absolute performance: 0.961655430061199
# SMA1 & SMA2: 10 65
# Absolute performance: 0.9625615893489324
# SMA1 & SMA2: 10 70
# Absolute performance: 0.9651760673628396
# SMA1 & SMA2: 10 75
# Absolute performance: 0.9874714576276062
# SMA1 & SMA2: 15 40
# Absolute performance: 0.9860616908185968
# SMA1 & SMA2: 15 45
# Absolute performance: 1.0068467888099524
# SMA1 & SMA2: 15 50
# Absolute performance: 0.9839270383230738
# SMA1 & SMA2: 15 55
# Absolute performance: 0.9723451663979492
# SMA1 & SMA2: 15 60
# Absolute performance: 0.9739997223653889
# SMA1 & SMA2: 15 65
# Absolute performance: 0.9793526643913864
# SMA1 & SMA2: 15 70
# Absolute performance: 0.9811494821404924
# SMA1 & SMA2: 15 75
# ...

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',10, 40, '2026-1-1', '2026-7-9','H1')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 10 40
# Absolute performance: 0.9920416015088414
# (np.float64(0.99), np.float64(-0.05))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((5,15,5), (20,50,5))
# Out:
# SMA1 & SMA2: 5 20
# Absolute performance: 1.0584267283130377
# SMA1 & SMA2: 5 25
# Absolute performance: 1.0523806319430484
# SMA1 & SMA2: 5 30
# Absolute performance: 1.0460865927694636
# SMA1 & SMA2: 5 35
# Absolute performance: 1.0218108802477197
# SMA1 & SMA2: 5 40
# Absolute performance: 1.0331404190970979
# SMA1 & SMA2: 5 45
# Absolute performance: 1.0387534479339413
# SMA1 & SMA2: 10 20
# Absolute performance: 1.049814373927303
# SMA1 & SMA2: 10 25
# Absolute performance: 1.025142093430571
# SMA1 & SMA2: 10 30
# Absolute performance: 1.0311663229683208
# SMA1 & SMA2: 10 35
# Absolute performance: 1.0396398921646108
# SMA1 & SMA2: 10 40
# Absolute performance: 0.9920416015088414
# SMA1 & SMA2: 10 45
# Absolute performance: 0.9887861700796327
# SMA1 & SMA2: 5 20
# Absolute performance: 1.0584267283130377
# CPU times: user 38.7 ms, sys: 0 ns, total: 38.7 ms
# Wall time: 38.8 ms
# (array([ 5., 20.]), np.float64(1.06))

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',5, 20, '2026-1-1', '2026-7-9','H1')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 5 20
# Absolute performance: 1.0584267283130377
# (np.float64(1.06), np.float64(0.02))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',5, 20, '2026-4-1', '2026-7-9','M15')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 5 20
# Absolute performance: 0.9516565223746404
# (np.float64(0.95), np.float64(-0.07))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((3,10,2), (10,30,5))
# Out:
# SMA1 & SMA2: 3 10
# Absolute performance: 0.9850662500276856
# SMA1 & SMA2: 3 15
# Absolute performance: 0.9402086628888093
# SMA1 & SMA2: 3 20
# Absolute performance: 0.9249579165177965
# SMA1 & SMA2: 3 25
# Absolute performance: 0.9591013249387992
# SMA1 & SMA2: 5 10
# Absolute performance: 0.9827080019960699
# SMA1 & SMA2: 5 15
# Absolute performance: 0.9737182729615513
# SMA1 & SMA2: 5 20
# Absolute performance: 0.9516565223746404
# SMA1 & SMA2: 5 25
# Absolute performance: 0.9417400227693613
# SMA1 & SMA2: 7 10
# Absolute performance: 0.9774374196538391
# SMA1 & SMA2: 7 15
# Absolute performance: 0.9593741865353322
# SMA1 & SMA2: 7 20
# Absolute performance: 0.9366348541540784
# SMA1 & SMA2: 7 25
# Absolute performance: 0.9740225080256956
# SMA1 & SMA2: 9 10
# Absolute performance: 0.9489932400296778
# SMA1 & SMA2: 9 15
# Absolute performance: 0.952489824341296
# SMA1 & SMA2: 9 20
# Absolute performance: 0.9470220617898515
# SMA1 & SMA2: 9 25
# ...

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',3, 15, '2026-4-1', '2026-7-9','M5')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 3 15
# Absolute performance: 0.9902946771821659
# (np.float64(0.99), np.float64(-0.03))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((2,5,1), (5,20,5))
# Out:
# SMA1 & SMA2: 2 5
# Absolute performance: 1.0220958954635975
# SMA1 & SMA2: 2 10
# Absolute performance: 0.9449407148913189
# SMA1 & SMA2: 2 15
# Absolute performance: 0.9622228310731161
# SMA1 & SMA2: 3 5
# Absolute performance: 1.0393402869863244
# SMA1 & SMA2: 3 10
# Absolute performance: 0.9760457845077817
# SMA1 & SMA2: 3 15
# Absolute performance: 0.9902946771821659
# SMA1 & SMA2: 4 5
# Absolute performance: 1.0143441535482784
# SMA1 & SMA2: 4 10
# Absolute performance: 1.0060921157737603
# SMA1 & SMA2: 4 15
# Absolute performance: 0.9939248889923318
# SMA1 & SMA2: 3 5
# Absolute performance: 1.0393402869863244
# CPU times: user 44.2 ms, sys: 0 ns, total: 44.2 ms
# Wall time: 44.5 ms
# (array([3., 5.]), np.float64(1.04))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY',2 , 6, '2026-4-1', '2026-7-9','M1')
smabt.run_strategy()
# Out:
# SMA1 & SMA2: 2 6
# Absolute performance: 0.8909981872210282
# (np.float64(0.89), np.float64(-0.13))

# %%
smabt.plot_results()

# %%
# %%time
smabt.optimize_parameters((1,3,1), (3,10,1))
# Out:
# SMA1 & SMA2: 1 3
# Absolute performance: 0.8380026116919203
# SMA1 & SMA2: 1 4
# Absolute performance: 0.8403478874661717
# SMA1 & SMA2: 1 5
# Absolute performance: 0.8318875243748943
# SMA1 & SMA2: 1 6
# Absolute performance: 0.8182464987055277
# SMA1 & SMA2: 1 7
# Absolute performance: 0.8396120833465528
# SMA1 & SMA2: 1 8
# Absolute performance: 0.8525811424998072
# SMA1 & SMA2: 1 9
# Absolute performance: 0.8655662920021073
# SMA1 & SMA2: 2 3
# Absolute performance: 0.9064915702997822
# SMA1 & SMA2: 2 4
# Absolute performance: 0.9171826438262933
# SMA1 & SMA2: 2 5
# Absolute performance: 0.8948864748790606
# SMA1 & SMA2: 2 6
# Absolute performance: 0.8909981872210282
# SMA1 & SMA2: 2 7
# Absolute performance: 0.9008077444570013
# SMA1 & SMA2: 2 8
# Absolute performance: 0.9081113867547338
# SMA1 & SMA2: 2 9
# Absolute performance: 0.9192240299922332
# SMA1 & SMA2: 2 4
# Absolute performance: 0.9171826438262933
# CPU times: user 139 ms, sys: 19.3 ms, total: 158 ms
# ...

# %%
smabt.plot_results()
