# %%
import SMAVectorBacktester as SMA

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 9, 26, '2020-1-1', '2026-7-1','D')
smabt.run_strategy()
# Out:
# (np.float64(1.28), np.float64(-0.2))

# %%
# %%time
smabt.optimize_parameters((1,10,2), (100,300,2))
# Out:
# CPU times: user 899 ms, sys: 0 ns, total: 899 ms
# Wall time: 943 ms
# (array([  9., 102.]), np.float64(1.61))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 9, 26, '2000-1-1', '2010-1-1','D')
smabt.run_strategy()
# Out:
# (np.float64(1.28), np.float64(0.53))

# %%
# %%time
smabt.optimize_parameters((1,10,2), (100,300,2))
# Out:
# CPU times: user 967 ms, sys: 7.54 ms, total: 974 ms
# Wall time: 1.02 s
# (array([  9., 298.]), np.float64(0.97))

# %%
smabt.plot_results()

# %%
smabt = SMA.SMAVectorBacktester('USD_JPY', 9, 26, '2010-1-1', '2020-1-1','D')
smabt.run_strategy()
# Out:
# (np.float64(0.74), np.float64(-0.47))

# %%
# %%time
smabt.optimize_parameters((1,10,2), (100,300,2))
# Out:
# CPU times: user 991 ms, sys: 7.33 ms, total: 998 ms
# Wall time: 1.05 s
# (array([  1., 156.]), np.float64(1.47))

# %%
smabt.plot_results()
