# %%
import ScikitVectorBacktester as SCI

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2002-5-6', '2010-12-31', 10000, model='logistic')

# %%
scibt.run_strategy('2002-5-6', '2008-12-31', '2009-1-1', '2009-12-31')
# Out:
# (np.float64(10895.0), np.float64(641.89))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,51,1))
# Out:
# (34, np.float64(12453.59))

# %%
scibt.run_strategy('2002-5-6', '2008-12-31',
                   '2009-1-1', '2009-12-31', lags=34)
# Out:
# (np.float64(12453.59), np.float64(2200.47))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000, model='logistic')

# %%
scibt.run_strategy('2010-1-1', '2018-12-31','2019-1-1', '2019-12-31')
# Out:
# (np.float64(10327.8), np.float64(415.58))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1))
# Out:
# (20, np.float64(11240.27))

# %%
scibt.run_strategy('2010-1-1', '2018-12-31', '2019-1-1', '2019-12-31', lags=20)
# Out:
# (np.float64(11240.27), np.float64(1328.05))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2020-1-1', '2026-7-7', 10000, model='logistic')

# %%
scibt.run_strategy('2020-1-1', '2025-12-31', '2026-1-1', '2026-7-7')
# Out:
# (np.float64(10346.81), np.float64(0.0))

# %%
scibt.results['prediction'].value_counts()
# Out:
# prediction
# 1.0    133
# Name: count, dtype: int64

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1))
# Out:
# (27, np.float64(10398.47))

# %%
scibt.run_strategy('2020-1-1', '2025-12-31', '2026-1-1', '2026-7-7', lags=27)
# Out:
# (np.float64(10398.47), np.float64(51.66))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2021-12-1',
                                    '2022-12-31', 10000, model='logistic')

# %%
scibt.run_strategy('2022-1-1', '2022-12-31',
                   '2022-1-1', '2022-12-31')
# Out:
# (np.float64(11165.15), np.float64(-151.88))

# %%
scibt.plot_results()

# %%
scibt.run_strategy('2022-2-1', '2022-9-9',
                   '2022-9-5', '2022-10-20')
# Out:
# (np.float64(10529.34), np.float64(0.0))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1),
                          '2022-2-1', '2022-9-9',
                   '2022-2-1', '2022-9-9')
# Out:
# (42, np.float64(13888.6))

# %%
scibt.run_strategy('2022-2-1', '2022-9-9',
                   '2022-7-12', '2022-10-20', lags=42)
# Out:
# (np.float64(10334.21), np.float64(-195.13))

# %%
scibt.plot_results()

# %%
scibt.run_strategy('2022-2-1', '2022-10-9',
                   '2022-8-22', '2022-11-9', lags=33)
# Out:
# (np.float64(10114.09), np.float64(43.1))

# %%
scibt.plot_results()
