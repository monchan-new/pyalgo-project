# %%
import FixDate_ScikitVectorBacktester as SCI

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2002-5-6',
                                    '2010-12-31', 10000, model='logistic')

# %%
scibt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31', lags=15)
# Out:
# (np.float64(9300.88), np.float64(1245.28))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1),
                          '2002-5-6','2005-12-31',
                          '2006-1-1','2009-12-31')
# Out:
# (33, np.float64(14901.67))

# %%
scibt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31', lags=33)
# Out:
# (np.float64(14901.67), np.float64(7070.54))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2010-1-1',
                                    '2019-12-31', 10000, model='logistic')

# %%
scibt.run_strategy('2010-1-1', '2014-12-31',
                   '2015-1-1', '2019-12-31', lags=15)
# Out:
# (np.float64(8944.62), np.float64(-222.15))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1),
                          '2010-1-1','2014-12-31',
                          '2015-1-1','2019-12-31')
# Out:
# (3, np.float64(10898.11))

# %%
scibt.run_strategy('2010-1-1', '2014-12-31',
                   '2015-4-1', '2019-12-31', lags=3)
# Out:
# (np.float64(11004.16), np.float64(1916.69))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2020-1-1',
                                    '2026-7-7', 10000, model='logistic')

# %%
scibt.run_strategy('2020-1-1', '2023-12-31',
                   '2024-4-1', '2026-7-7', lags=15)
# Out:
# (np.float64(11558.09), np.float64(1087.79))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1),
                          '2020-1-1','2023-12-31',
                          '2024-1-1','2026-7-7')
# Out:
# (36, np.float64(13972.85))

# %%
scibt.run_strategy('2020-1-1', '2023-12-31',
                   '2024-1-1', '2026-7-7', lags=36)
# Out:
# (np.float64(13972.85), np.float64(3164.84))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((1461,1462,1),(1,50,1),"2024-1-1", 919)
# Out:
# lags 1
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 2
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 3
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 4
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 5
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 6
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 7
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 8
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 9
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 10
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 11
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 12
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 13
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 14
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 15
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 16
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 17
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 18
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 19
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 20
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 21
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 22
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 23
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 24
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 25
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 26
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 27
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 28
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 29
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 30
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 31
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 32
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 33
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 34
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 35
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 36
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 37
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 38
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 39
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 40
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 41
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 42
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 43
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 44
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 45
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 46
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 47
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 48
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 49
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# lags 36
# start/end_in 2020-01-01 00:00:00 2023-12-31 00:00:00
# start/end_out 2024-01-01 00:00:00 2026-07-07 00:00:00
# ((1461, 36), np.float64(13972.85))

# %%
scibt.run_strategy('2020-1-1', '2023-12-31',
                   '2024-1-1', '2026-7-7', lags=36)
# Out:
# (np.float64(13972.85), np.float64(3164.84))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2020-1-1',
                                    '2026-7-7', 10000, model='logistic')

# %%
scibt.run_strategy('2020-1-1', '2023-12-31',
                   '2026-1-1', '2026-7-7', lags=36)
# Out:
# (np.float64(9563.83), np.float64(-890.27))

# %%
scibt.plot_results()
