# %%
import FixDate_ScikitVectorBacktester as SCI

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2002-5-6',
                                    '2010-12-31', 10000, model='logistic')

# %%
scibt.optimize_parameters((3,50,1),
                          '2002-5-6','2005-12-31',
                          '2002-5-6','2005-12-31')
# Out:
# (46, np.float64(21882.14))

# %%
scibt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31', lags=46)
# Out:
# (np.float64(11414.79), np.float64(3543.9))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2010-1-1',
                                    '2019-12-31', 10000, model='logistic')

# %%
scibt.optimize_parameters((3,50,1),
                          '2010-1-1','2014-12-31',
                          '2010-1-1','2014-12-31')
# Out:
# (42, np.float64(24839.96))

# %%
scibt.run_strategy('2010-1-1', '2014-12-31',
                   '2015-1-1', '2019-12-31', lags=42)
# Out:
# (np.float64(7066.6), np.float64(-1975.78))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2020-1-1',
                                    '2026-7-7', 10000, model='logistic')

# %%
scibt.optimize_parameters((3,50,1),
                          '2020-1-1','2023-12-31',
                          '2020-1-1','2023-12-31')
# Out:
# (17, np.float64(15681.84))

# %%
scibt.run_strategy('2020-1-1', '2023-12-31',
                   '2024-1-1', '2026-7-7', lags=17)
# Out:
# (np.float64(12004.84), np.float64(1015.13))

# %%
scibt.plot_results()
