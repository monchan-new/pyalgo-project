# %%
import ScikitVectorBacktester as SCI

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2002-5-6',
                                    '2010-12-31', 10000, model='logistic')

# %%
scibt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31')
# Out:
# (np.float64(12461.03), np.float64(4448.46))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,51,1),
                          '2002-5-6','2005-12-31',
                          '2002-5-6','2005-12-31')
# Out:
# (3, np.float64(10838.22))

# %%
scibt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31', lags=3)
# Out:
# (np.float64(12461.03), np.float64(4448.46))

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2010-1-1',
                                    '2019-12-31', 10000, model='logistic')

# %%
scibt.run_strategy('2010-1-1', '2014-12-31',
                   '2015-1-1', '2019-12-31')
# Out:
# (np.float64(10978.11), np.float64(1802.21))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1),
                          '2010-1-1','2014-12-31',
                          '2010-1-1','2014-12-31')
# Out:
# (44, np.float64(14174.82))

# %%
scibt.run_strategy('2010-1-1', '2014-12-31',
                   '2015-1-1', '2019-12-31', lags=44)
# Out:
# (np.float64(7620.19), np.float64(-1455.74))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('USD_JPY', '2020-1-1',
                                    '2026-7-7', 10000, model='logistic')

# %%
scibt.run_strategy('2020-1-1', '2023-12-31',
                   '2024-1-1', '2026-7-7')
# Out:
# (np.float64(11209.7), np.float64(0.7))

# %%
scibt.plot_results()

# %%
scibt.optimize_parameters((3,50,1),
                          '2020-1-1','2023-12-31',
                          '2020-1-1','2023-12-31')
# Out:
# (31, np.float64(14576.61))

# %%
scibt.run_strategy('2020-1-1', '2023-12-31',
                   '2024-1-1', '2026-7-7', lags=31)
# Out:
# (np.float64(8772.82), np.float64(-1978.14))

# %%
scibt.plot_results()
