# %%
import ScikitVectorBacktester as SCI

# %%
scibt = SCI.ScikitVectorBacktester('EUR=',
                                   '2010-1-1', '2019-12-31',
                                   10000, 0.0, 'logistic')

# %%
scibt.run_strategy('2015-1-1', '2019-12-31',
                  '2015-1-1', '2019-12-31', lags=15       )
# Out:
# (np.float64(12633.55), np.float64(2630.88))

# %%
scibt.run_strategy('2016-1-1', '2018-12-31',
                   '2019-1-1', '2020-12-31', lags=15                )
# Out:
# (np.float64(10459.4), np.float64(608.79))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('GDX',
                                   '2010-1-1', '2019-12-31',
                                   10000, 0.00, 'logistic')

# %%
scibt.run_strategy('2013-1-1', '2017-12-31',
                   '2018-1-1', '2018-12-31', lags=10)
# Out:
# (np.float64(12116.78), np.float64(3462.69))

# %%
scibt.plot_results()

# %%
scibt = SCI.ScikitVectorBacktester('GDX',
                                   '2010-1-1', '2019-12-31',
                                   10000, 0.0025, 'logistic')

# %%
scibt.run_strategy('2013-1-1', '2017-12-31',
                   '2018-1-1', '2018-12-31', lags=10)
# Out:
# (np.float64(9157.66), np.float64(503.58))

# %%
scibt.plot_results()
