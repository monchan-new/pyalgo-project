# %%
import MRVectorBacktester as MR

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2002-5-6', '2005-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 91
# Absolute performance: 9607.97594110674
# (np.float64(9607.98), np.float64(403.0))

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 126
# Absolute performance: 9208.254639659033
# SMA & threshold: 20 1.5
# Number of trades: 110
# Absolute performance: 9817.434339779338
# SMA & threshold: 20 2.0
# Number of trades: 90
# Absolute performance: 10728.753591778832
# SMA & threshold: 25 1.0
# Number of trades: 101
# Absolute performance: 9217.762837730015
# SMA & threshold: 25 1.5
# Number of trades: 91
# Absolute performance: 9607.97594110674
# SMA & threshold: 25 2.0
# Number of trades: 67
# Absolute performance: 9457.342445005472
# SMA & threshold: 30 1.0
# Number of trades: 95
# Absolute performance: 10496.805909996128
# SMA & threshold: 30 1.5
# Number of trades: 75
# Absolute performance: 10301.833593766476
# SMA & threshold: 30 2.0
# Number of trades: 55
# Absolute performance: 10373.308053124683
# SMA & threshold: 35 1.0
# Number of trades: 91
# Absolute performance: 11119.126146460512
# SMA & threshold: 35 1.5
# Number of trades: 69
# Absolute performance: 11218.851248446312
# SMA & threshold: 35 2.0
# Number of trades: 47
# Absolute performance: 10869.141636760878
# SMA & threshold: 40 1.0
# Number of trades: 87
# Absolute performance: 11788.418514499377
# SMA & threshold: 40 1.5
# Number of trades: 63
# Absolute performance: 11736.176894917757
# SMA & threshold: 40 2.0
# Number of trades: 43
# Absolute performance: 10944.967390421545
# SMA & threshold: 45 1.0
# Number of trades: 69
# Absolute performance: 10988.99589902982
# SMA & threshold: 45 1.5
# Number of trades: 57
# Absolute performance: 11863.815170197704
# SMA & threshold: 45 2.0
# Number of trades: 39
# Absolute performance: 10698.78912475624
# SMA & threshold: 50 1.0
# Number of trades: 65
# Absolute performance: 10946.064456296495
# SMA & threshold: 50 1.5
# Number of trades: 57
# Absolute performance: 12238.023284889121
# SMA & threshold: 50 2.0
# Number of trades: 34
# Absolute performance: 10671.996131982683
# SMA & threshold: 50 1.5
# Number of trades: 57
# Absolute performance: 12238.023284889121
# ((50, 1.5), np.float64(12238.02))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2006-1-1', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=50, threshold=1.5)
# Out:
# SMA & threshold: 50 1.5
# Number of trades: 45
# Absolute performance: 8466.484049736404
# (np.float64(8466.48), np.float64(575.57))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2010-1-1', '2014-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 129
# Absolute performance: 11472.351930622526
# (np.float64(11472.35), np.float64(-1420.34))

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 189
# Absolute performance: 10847.249820711537
# SMA & threshold: 20 1.5
# Number of trades: 156
# Absolute performance: 10875.1055880415
# SMA & threshold: 20 2.0
# Number of trades: 104
# Absolute performance: 10421.128074335244
# SMA & threshold: 25 1.0
# Number of trades: 163
# Absolute performance: 10963.80281935682
# SMA & threshold: 25 1.5
# Number of trades: 129
# Absolute performance: 11472.351930622526
# SMA & threshold: 25 2.0
# Number of trades: 92
# Absolute performance: 10643.521649603186
# SMA & threshold: 30 1.0
# Number of trades: 141
# Absolute performance: 11222.743360912935
# SMA & threshold: 30 1.5
# Number of trades: 115
# Absolute performance: 11240.391163123955
# SMA & threshold: 30 2.0
# Number of trades: 78
# Absolute performance: 10372.337944187475
# SMA & threshold: 35 1.0
# Number of trades: 131
# Absolute performance: 10987.152947374314
# SMA & threshold: 35 1.5
# Number of trades: 97
# Absolute performance: 10733.708512033125
# SMA & threshold: 35 2.0
# Number of trades: 66
# Absolute performance: 9738.23216665072
# SMA & threshold: 40 1.0
# Number of trades: 109
# Absolute performance: 9566.392173931932
# SMA & threshold: 40 1.5
# Number of trades: 85
# Absolute performance: 9930.104232568918
# SMA & threshold: 40 2.0
# Number of trades: 47
# Absolute performance: 8031.8574889225165
# SMA & threshold: 45 1.0
# Number of trades: 103
# Absolute performance: 9901.79084259829
# SMA & threshold: 45 1.5
# Number of trades: 79
# Absolute performance: 9674.40476595156
# SMA & threshold: 45 2.0
# Number of trades: 45
# Absolute performance: 8902.783431328278
# SMA & threshold: 50 1.0
# Number of trades: 97
# Absolute performance: 9930.117547992611
# SMA & threshold: 50 1.5
# Number of trades: 69
# Absolute performance: 9600.377432301635
# SMA & threshold: 50 2.0
# Number of trades: 45
# Absolute performance: 9265.023163738517
# SMA & threshold: 25 1.5
# Number of trades: 129
# Absolute performance: 11472.351930622526
# ((25, 1.5), np.float64(11472.35))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2015-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 96
# Absolute performance: 9530.892976446095
# (np.float64(9530.89), np.float64(515.67))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2020-1-1', '2023-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 71
# Absolute performance: 8364.949508984886
# (np.float64(8364.95), np.float64(-4626.36))

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 101
# Absolute performance: 7259.889699581259
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 7373.518475367453
# SMA & threshold: 20 2.0
# Number of trades: 63
# Absolute performance: 8040.14542637101
# SMA & threshold: 25 1.0
# Number of trades: 87
# Absolute performance: 8059.629263971881
# SMA & threshold: 25 1.5
# Number of trades: 71
# Absolute performance: 8364.949508984886
# SMA & threshold: 25 2.0
# Number of trades: 47
# Absolute performance: 8028.43734199078
# SMA & threshold: 30 1.0
# Number of trades: 85
# Absolute performance: 8552.350782671601
# SMA & threshold: 30 1.5
# Number of trades: 69
# Absolute performance: 8468.60844440629
# SMA & threshold: 30 2.0
# Number of trades: 45
# Absolute performance: 8067.125648206067
# SMA & threshold: 35 1.0
# Number of trades: 73
# Absolute performance: 8425.287223485419
# SMA & threshold: 35 1.5
# Number of trades: 57
# Absolute performance: 8323.479607705322
# SMA & threshold: 35 2.0
# Number of trades: 43
# Absolute performance: 8466.023468240337
# SMA & threshold: 40 1.0
# Number of trades: 67
# Absolute performance: 8722.30421052927
# SMA & threshold: 40 1.5
# Number of trades: 47
# Absolute performance: 8123.292542550436
# SMA & threshold: 40 2.0
# Number of trades: 39
# Absolute performance: 9143.090392994241
# SMA & threshold: 45 1.0
# Number of trades: 55
# Absolute performance: 8293.632406210074
# SMA & threshold: 45 1.5
# Number of trades: 47
# Absolute performance: 8370.69247285546
# SMA & threshold: 45 2.0
# Number of trades: 35
# Absolute performance: 8777.07752343476
# SMA & threshold: 50 1.0
# Number of trades: 53
# Absolute performance: 8627.830606921218
# SMA & threshold: 50 1.5
# Number of trades: 45
# Absolute performance: 8817.12252665246
# SMA & threshold: 50 2.0
# Number of trades: 33
# Absolute performance: 9098.922983323402
# SMA & threshold: 40 2.0
# Number of trades: 39
# Absolute performance: 9143.090392994241
# ((40, 2.0), np.float64(9143.09))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2024-1-1', '2026-7-7', 10000, 0.000025)
mrbt.run_strategy(SMA=40, threshold=2.0)
# Out:
# SMA & threshold: 40 2.0
# Number of trades: 28
# Absolute performance: 10465.39703901024
# (np.float64(10465.4), np.float64(-950.88))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H4")
mrbt.run_strategy(SMA=20, threshold=1.5)
# Out:
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# (np.float64(10241.08), np.float64(-82.6))

# %%
mrbt.plot_results()

# %%
mrbt.optimize_parameters((10, 35, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 10 1.0
# Number of trades: 147
# Absolute performance: 9634.314843442742
# SMA & threshold: 10 1.5
# Number of trades: 119
# Absolute performance: 9756.748210000367
# SMA & threshold: 10 2.0
# Number of trades: 63
# Absolute performance: 9966.95633461395
# SMA & threshold: 15 1.0
# Number of trades: 119
# Absolute performance: 9972.920012515697
# SMA & threshold: 15 1.5
# Number of trades: 95
# Absolute performance: 10010.8245403759
# SMA & threshold: 15 2.0
# Number of trades: 61
# Absolute performance: 9952.869268448816
# SMA & threshold: 20 1.0
# Number of trades: 93
# Absolute performance: 10084.140552505867
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# SMA & threshold: 20 2.0
# Number of trades: 51
# Absolute performance: 10159.619160497377
# SMA & threshold: 25 1.0
# Number of trades: 73
# Absolute performance: 9908.832871096374
# SMA & threshold: 25 1.5
# Number of trades: 61
# Absolute performance: 9975.590308500334
# SMA & threshold: 25 2.0
# Number of trades: 45
# Absolute performance: 9946.250961394255
# SMA & threshold: 30 1.0
# Number of trades: 65
# Absolute performance: 9888.828992327422
# SMA & threshold: 30 1.5
# Number of trades: 49
# Absolute performance: 9844.953692184374
# SMA & threshold: 30 2.0
# Number of trades: 36
# Absolute performance: 10042.677523832186
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# ((20, 1.5), np.float64(10241.08))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H1")
mrbt.run_strategy(SMA=10, threshold=1.5)
# Out:
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# (np.float64(9945.88), np.float64(-369.17))

# %%
mrbt.optimize_parameters((5, 20, 5), (1, 2, 0.5))
# Out:
# SMA & threshold: 5 1.0
# Number of trades: 958
# Absolute performance: 10298.591798317968
# SMA & threshold: 5 1.5
# Number of trades: 502
# Absolute performance: 10354.942522136376
# SMA & threshold: 10 1.0
# Number of trades: 632
# Absolute performance: 10201.741665178231
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# SMA & threshold: 15 1.0
# Number of trades: 466
# Absolute performance: 9784.800378792283
# SMA & threshold: 15 1.5
# Number of trades: 366
# Absolute performance: 9679.55778733525
# SMA & threshold: 5 1.5
# Number of trades: 502
# Absolute performance: 10354.942522136376
# ((5, 1.5), np.float64(10354.94))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H1")
mrbt.run_strategy(SMA=10, threshold=1.5)
# Out:
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# (np.float64(9945.88), np.float64(-369.17))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M5")
mrbt.run_strategy(SMA=3, threshold=1)
# Out:
# SMA & threshold: 3 1
# Number of trades: 2436
# Absolute performance: 9460.376643116258
# (np.float64(9460.38), np.float64(-685.18))

# %%
mrbt.optimize_parameters((2, 5, 1), (1, 1.5, 0.5))
# Out:
# SMA & threshold: 2 1.0
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 3 1.0
# Number of trades: 2436
# Absolute performance: 9460.376643116258
# SMA & threshold: 4 1.0
# Number of trades: 2617
# Absolute performance: 9450.84380740328
# SMA & threshold: 2 1.0
# Number of trades: 0
# Absolute performance: 10000.0
# ((2, 1.0), np.float64(10000.0))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M5")
mrbt.run_strategy(SMA=2, threshold=1)
# Out:
# SMA & threshold: 2 1
# Number of trades: 0
# Absolute performance: 10000.0
# (np.float64(10000.0), np.float64(-145.56))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M1")
mrbt.run_strategy(SMA=2, threshold=1)
# Out:
# SMA & threshold: 2 1
# Number of trades: 0
# Absolute performance: 10000.0
# (np.float64(10000.0), np.float64(-145.5))

# %%
mrbt.optimize_parameters((1, 3, 1), (0.5, 1, 0.5))
# Out:
# SMA & threshold: 1 0.5
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 2 0.5
# Number of trades: 20251
# Absolute performance: 6189.979526405616
# SMA & threshold: 1 0.5
# Number of trades: 0
# Absolute performance: 10000.0
# ((1, 0.5), np.float64(10000.0))

# %%
mrbt.plot_results()
