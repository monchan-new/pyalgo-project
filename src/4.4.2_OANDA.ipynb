# %%
import MRVectorBacktester as MR
mrbt = MR.MRVectorBacktester('USD_JPY', '2000-1-1', '2010-1-1', 10000, 0.000025)

# %%
mrbt.optimize_parameters((1,50,1),(1,20,1))
# Out:
# SMA & threshold: 1 1
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 2
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 3
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 4
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 5
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 6
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 7
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 8
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 9
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 10
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 11
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 12
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 13
# Number of trades: 0
# ...

# %%
mrbt.run_strategy(SMA=17, threshold=4.0)
# Out:
# SMA & threshold: 17 4.0
# Number of trades: 16
# Absolute performance: 11729.31608425059
# (np.float64(11729.32), np.float64(4276.61))

# %%
mrbt.plot_results()

# %%
import MRVectorBacktester as MR
mrbt = MR.MRVectorBacktester('USD_JPY', '2010-1-1', '2020-1-1', 10000, 0.001)

# %%
mrbt.optimize_parameters((1,50,1),(1,20,1))
# Out:
# SMA & threshold: 1 1
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 2
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 3
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 4
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 5
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 6
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 7
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 8
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 9
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 10
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 11
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 12
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 13
# Number of trades: 0
# ...

# %%
mrbt.run_strategy(SMA=19, threshold=3.0)
# Out:
# Number of trades: 47
# (np.float64(12050.22), np.float64(-42.67))

# %%
mrbt.plot_results()

# %%
import MRVectorBacktester as MR
mrbt = MR.MRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-1', 10000, 0.001)

# %%
mrbt.optimize_parameters((1,50,1),(1,20,1))
# Out:
# SMA & threshold: 1 1
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 2
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 3
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 4
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 5
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 6
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 7
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 8
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 9
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 10
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 11
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 12
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 1 13
# Number of trades: 0
# ...

# %%
mrbt.run_strategy(SMA=11, threshold=4.0)
# Out:
# SMA & threshold: 11 4.0
# Number of trades: 24
# Absolute performance: 11940.777551671772
# (np.float64(11940.78), np.float64(-2818.41))

# %%
mrbt.plot_results()

# %%
import MRVectorBacktester as MR
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-1', 10000, 0.001, 'H4')

# %%
mrbt.optimize_parameters((1,50,1),(1,20,1))
# Out:
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 3
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 7
# Number of trades: 3
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# Number of trades: 1
# ...

# %%
mrbt.run_strategy(SMA=31, threshold=4.0)
# Out:
# Number of trades: 3
# (np.float64(10116.27), np.float64(-235.21))

# %%
mrbt.plot_results()
