# %%
import MRVectorBacktester as MR

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2009-1-1', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 23
# Absolute performance: 10925.214865032784
# (np.float64(10925.21), np.float64(674.42))

# %%
mrbt.plot_results()

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 33
# Absolute performance: 10178.264600386829
# SMA & threshold: 20 1.5
# Number of trades: 29
# Absolute performance: 10299.12440143782
# SMA & threshold: 20 2.0
# Number of trades: 23
# Absolute performance: 11009.059237704067
# SMA & threshold: 25 1.0
# Number of trades: 25
# Absolute performance: 10132.382808767044
# SMA & threshold: 25 1.5
# Number of trades: 23
# Absolute performance: 10925.214865032784
# SMA & threshold: 25 2.0
# Number of trades: 18
# Absolute performance: 11298.69941256716
# SMA & threshold: 30 1.0
# Number of trades: 27
# Absolute performance: 10153.254138818154
# SMA & threshold: 30 1.5
# Number of trades: 21
# Absolute performance: 10435.422135636562
# SMA & threshold: 30 2.0
# Number of trades: 16
# Absolute performance: 11265.868490081657
# SMA & threshold: 35 1.0
# Number of trades: 23
# Absolute performance: 10415.474262427371
# SMA & threshold: 35 1.5
# Number of trades: 17
# Absolute performance: 10308.181783073973
# SMA & threshold: 35 2.0
# Number of trades: 15
# Absolute performance: 10765.417121268847
# SMA & threshold: 40 1.0
# Number of trades: 21
# Absolute performance: 10424.445885828189
# SMA & threshold: 40 1.5
# Number of trades: 17
# Absolute performance: 10835.580493368603
# SMA & threshold: 40 2.0
# Number of trades: 15
# Absolute performance: 11212.735552871818
# SMA & threshold: 45 1.0
# Number of trades: 21
# Absolute performance: 10703.883556353372
# SMA & threshold: 45 1.5
# Number of trades: 17
# Absolute performance: 10966.320916178467
# SMA & threshold: 45 2.0
# Number of trades: 13
# Absolute performance: 11048.089291328333
# SMA & threshold: 50 1.0
# Number of trades: 19
# Absolute performance: 10889.29804544375
# SMA & threshold: 50 1.5
# Number of trades: 13
# Absolute performance: 10905.913315399976
# SMA & threshold: 50 2.0
# Number of trades: 13
# Absolute performance: 11322.936054183503
# SMA & threshold: 50 2.0
# Number of trades: 13
# Absolute performance: 11322.936054183503
# ((50, 2.0), np.float64(11322.94))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2009-1-1', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=50, threshold=2.0)
# Out:
# SMA & threshold: 50 2.0
# Number of trades: 13
# Absolute performance: 11322.936054183503
# (np.float64(11322.94), np.float64(1072.14))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY',  '2019-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 20
# Absolute performance: 10155.235678179755
# (np.float64(10155.24), np.float64(179.02))

# %%
mrbt.plot_results()

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 31
# Absolute performance: 10327.780150115463
# SMA & threshold: 20 1.5
# Number of trades: 28
# Absolute performance: 10450.863086478006
# SMA & threshold: 20 2.0
# Number of trades: 16
# Absolute performance: 10157.247964703662
# SMA & threshold: 25 1.0
# Number of trades: 33
# Absolute performance: 10600.682838154667
# SMA & threshold: 25 1.5
# Number of trades: 20
# Absolute performance: 10155.235678179755
# SMA & threshold: 25 2.0
# Number of trades: 14
# Absolute performance: 10103.628244854961
# SMA & threshold: 30 1.0
# Number of trades: 27
# Absolute performance: 10379.729288748076
# SMA & threshold: 30 1.5
# Number of trades: 24
# Absolute performance: 10399.665917428481
# SMA & threshold: 30 2.0
# Number of trades: 14
# Absolute performance: 10135.002691166566
# SMA & threshold: 35 1.0
# Number of trades: 24
# Absolute performance: 10500.392321976844
# SMA & threshold: 35 1.5
# Number of trades: 18
# Absolute performance: 10345.391078708728
# SMA & threshold: 35 2.0
# Number of trades: 10
# Absolute performance: 10188.816831356393
# SMA & threshold: 40 1.0
# Number of trades: 25
# Absolute performance: 10655.002060811392
# SMA & threshold: 40 1.5
# Number of trades: 18
# Absolute performance: 10499.78069433004
# SMA & threshold: 40 2.0
# Number of trades: 8
# Absolute performance: 10257.738259450125
# SMA & threshold: 45 1.0
# Number of trades: 20
# Absolute performance: 10476.889857328915
# SMA & threshold: 45 1.5
# Number of trades: 16
# Absolute performance: 10414.508787392588
# SMA & threshold: 45 2.0
# Number of trades: 6
# Absolute performance: 9997.162740326297
# SMA & threshold: 50 1.0
# Number of trades: 16
# Absolute performance: 10303.479996663462
# SMA & threshold: 50 1.5
# Number of trades: 10
# Absolute performance: 10064.727188980123
# SMA & threshold: 50 2.0
# Number of trades: 4
# Absolute performance: 9946.212026480685
# SMA & threshold: 40 1.0
# Number of trades: 25
# Absolute performance: 10655.002060811392
# ((40, 1.0), np.float64(10655.0))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY',  '2019-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=40, threshold=1.0)
# Out:
# SMA & threshold: 40 1.0
# Number of trades: 25
# Absolute performance: 10655.002060811392
# (np.float64(10655.0), np.float64(678.79))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-7', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 9
# Absolute performance: 10318.862254980308
# (np.float64(10318.86), np.float64(-17.86))

# %%
mrbt.plot_results()

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 15
# Absolute performance: 10413.637039139703
# SMA & threshold: 20 1.5
# Number of trades: 10
# Absolute performance: 10542.383556232315
# SMA & threshold: 20 2.0
# Number of trades: 6
# Absolute performance: 10345.70628682434
# SMA & threshold: 25 1.0
# Number of trades: 9
# Absolute performance: 10173.34636285003
# SMA & threshold: 25 1.5
# Number of trades: 9
# Absolute performance: 10318.862254980308
# SMA & threshold: 25 2.0
# Number of trades: 5
# Absolute performance: 10307.787651268927
# SMA & threshold: 30 1.0
# Number of trades: 9
# Absolute performance: 10344.842996189122
# SMA & threshold: 30 1.5
# Number of trades: 9
# Absolute performance: 10470.703844943991
# SMA & threshold: 30 2.0
# Number of trades: 5
# Absolute performance: 10383.079650778534
# SMA & threshold: 35 1.0
# Number of trades: 7
# Absolute performance: 10092.793450267556
# SMA & threshold: 35 1.5
# Number of trades: 7
# Absolute performance: 10329.626272239748
# SMA & threshold: 35 2.0
# Number of trades: 5
# Absolute performance: 10383.079650778534
# SMA & threshold: 40 1.0
# Number of trades: 5
# Absolute performance: 10062.088553414345
# SMA & threshold: 40 1.5
# Number of trades: 5
# Absolute performance: 10212.129243845146
# SMA & threshold: 40 2.0
# Number of trades: 2
# Absolute performance: 10106.950333473385
# SMA & threshold: 45 1.0
# Number of trades: 5
# Absolute performance: 10062.088553414345
# SMA & threshold: 45 1.5
# Number of trades: 5
# Absolute performance: 10182.893665616262
# SMA & threshold: 45 2.0
# Number of trades: 2
# Absolute performance: 10106.950333473385
# SMA & threshold: 50 1.0
# Number of trades: 5
# Absolute performance: 10143.824800947554
# SMA & threshold: 50 1.5
# Number of trades: 5
# Absolute performance: 10229.650189578098
# SMA & threshold: 50 2.0
# Number of trades: 2
# Absolute performance: 10153.35815044233
# SMA & threshold: 20 1.5
# Number of trades: 10
# Absolute performance: 10542.383556232315
# ((20, 1.5), np.float64(10542.38))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-7', 10000, 0.000025)
mrbt.run_strategy(SMA=20, threshold=1.5)
# Out:
# SMA & threshold: 20 1.5
# Number of trades: 10
# Absolute performance: 10542.383556232315
# (np.float64(10542.38), np.float64(205.66))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H4")
mrbt.run_strategy(SMA=20, threshold=1.5)
# Out:
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# (np.float64(10241.08), np.float64(-82.6))

# %%
mrbt.plot_results()

# %%
mrbt.optimize_parameters((10, 35, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 10 1.0
# Number of trades: 147
# Absolute performance: 9634.314843442742
# SMA & threshold: 10 1.5
# Number of trades: 119
# Absolute performance: 9756.748210000367
# SMA & threshold: 10 2.0
# Number of trades: 63
# Absolute performance: 9966.95633461395
# SMA & threshold: 15 1.0
# Number of trades: 119
# Absolute performance: 9972.920012515697
# SMA & threshold: 15 1.5
# Number of trades: 95
# Absolute performance: 10010.8245403759
# SMA & threshold: 15 2.0
# Number of trades: 61
# Absolute performance: 9952.869268448816
# SMA & threshold: 20 1.0
# Number of trades: 93
# Absolute performance: 10084.140552505867
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# SMA & threshold: 20 2.0
# Number of trades: 51
# Absolute performance: 10159.619160497377
# SMA & threshold: 25 1.0
# Number of trades: 73
# Absolute performance: 9908.832871096374
# SMA & threshold: 25 1.5
# Number of trades: 61
# Absolute performance: 9975.590308500334
# SMA & threshold: 25 2.0
# Number of trades: 45
# Absolute performance: 9946.250961394255
# SMA & threshold: 30 1.0
# Number of trades: 65
# Absolute performance: 9888.828992327422
# SMA & threshold: 30 1.5
# Number of trades: 49
# Absolute performance: 9844.953692184374
# SMA & threshold: 30 2.0
# Number of trades: 36
# Absolute performance: 10042.677523832186
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# ((20, 1.5), np.float64(10241.08))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H1")
mrbt.run_strategy(SMA=10, threshold=1.5)
# Out:
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# (np.float64(9945.88), np.float64(-369.17))

# %%
mrbt.optimize_parameters((5, 20, 5), (1, 2, 0.5))
# Out:
# SMA & threshold: 5 1.0
# Number of trades: 958
# Absolute performance: 10298.591798317968
# SMA & threshold: 5 1.5
# Number of trades: 502
# Absolute performance: 10354.942522136376
# SMA & threshold: 10 1.0
# Number of trades: 632
# Absolute performance: 10201.741665178231
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# SMA & threshold: 15 1.0
# Number of trades: 466
# Absolute performance: 9784.800378792283
# SMA & threshold: 15 1.5
# Number of trades: 366
# Absolute performance: 9679.55778733525
# SMA & threshold: 5 1.5
# Number of trades: 502
# Absolute performance: 10354.942522136376
# ((5, 1.5), np.float64(10354.94))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H1")
mrbt.run_strategy(SMA=10, threshold=1.5)
# Out:
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# (np.float64(9945.88), np.float64(-369.17))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M5")
mrbt.run_strategy(SMA=3, threshold=1)
# Out:
# SMA & threshold: 3 1
# Number of trades: 2436
# Absolute performance: 9460.376643116258
# (np.float64(9460.38), np.float64(-685.18))

# %%
mrbt.optimize_parameters((2, 5, 1), (1, 1.5, 0.5))
# Out:
# SMA & threshold: 2 1.0
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 3 1.0
# Number of trades: 2436
# Absolute performance: 9460.376643116258
# SMA & threshold: 4 1.0
# Number of trades: 2617
# Absolute performance: 9450.84380740328
# SMA & threshold: 2 1.0
# Number of trades: 0
# Absolute performance: 10000.0
# ((2, 1.0), np.float64(10000.0))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M5")
mrbt.run_strategy(SMA=2, threshold=1)
# Out:
# SMA & threshold: 2 1
# Number of trades: 0
# Absolute performance: 10000.0
# (np.float64(10000.0), np.float64(-145.56))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M1")
mrbt.run_strategy(SMA=2, threshold=1)
# Out:
# SMA & threshold: 2 1
# Number of trades: 0
# Absolute performance: 10000.0
# (np.float64(10000.0), np.float64(-145.5))

# %%
mrbt.optimize_parameters((1, 3, 1), (0.5, 1, 0.5))
# Out:
# SMA & threshold: 1 0.5
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 2 0.5
# Number of trades: 20251
# Absolute performance: 6189.979526405616
# SMA & threshold: 1 0.5
# Number of trades: 0
# Absolute performance: 10000.0
# ((1, 0.5), np.float64(10000.0))

# %%
mrbt.plot_results()
