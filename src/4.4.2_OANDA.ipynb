# %%
import MRVectorBacktester as MR

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2002-5-6', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 191
# Absolute performance: 10078.205956128726
# (np.float64(10078.21), np.float64(2806.0))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2002-5-6', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=30, threshold=1.5)
# Out:
# SMA & threshold: 30 1.5
# Number of trades: 167
# Absolute performance: 10425.319229134251
# (np.float64(10425.32), np.float64(3153.12))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2002-5-6', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=42, threshold=1.5)
# Out:
# SMA & threshold: 42 1.5
# Number of trades: 123
# Absolute performance: 11255.569526447447
# (np.float64(11255.57), np.float64(3983.37))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2002-5-6', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=50, threshold=1.5)
# Out:
# SMA & threshold: 50 1.5
# Number of trades: 105
# Absolute performance: 10572.491090997273
# (np.float64(10572.49), np.float64(3300.29))

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 267
# Absolute performance: 8098.089305319285
# SMA & threshold: 20 1.5
# Number of trades: 229
# Absolute performance: 9356.136688063212
# SMA & threshold: 20 2.0
# Number of trades: 183
# Absolute performance: 11170.802961896892
# SMA & threshold: 25 1.0
# Number of trades: 221
# Absolute performance: 8569.950971166945
# SMA & threshold: 25 1.5
# Number of trades: 191
# Absolute performance: 10078.205956128726
# SMA & threshold: 25 2.0
# Number of trades: 138
# Absolute performance: 9759.804200064102
# SMA & threshold: 30 1.0
# Number of trades: 205
# Absolute performance: 10130.869857201707
# SMA & threshold: 30 1.5
# Number of trades: 167
# Absolute performance: 10425.319229134251
# SMA & threshold: 30 2.0
# Number of trades: 124
# Absolute performance: 11028.464375657628
# SMA & threshold: 35 1.0
# Number of trades: 183
# Absolute performance: 9821.914119420413
# SMA & threshold: 35 1.5
# Number of trades: 137
# ...

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2002-5-6', '2009-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=45, threshold=1.5)
# Out:
# SMA & threshold: 45 1.5
# Number of trades: 119
# Absolute performance: 11609.499099340901
# (np.float64(11609.5), np.float64(4337.3))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 228
# Absolute performance: 11241.931820371998
# (np.float64(11241.93), np.float64(-440.26))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=30, threshold=1.5)
# Out:
# SMA & threshold: 30 1.5
# Number of trades: 206
# Absolute performance: 11386.457592636825
# (np.float64(11386.46), np.float64(-295.73))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=42, threshold=1.5)
# Out:
# SMA & threshold: 42 1.5
# Number of trades: 154
# Absolute performance: 9619.846314887602
# (np.float64(9619.85), np.float64(-2062.34))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=50, threshold=1.5)
# Out:
# SMA & threshold: 50 1.5
# Number of trades: 124
# Absolute performance: 9456.136098951076
# (np.float64(9456.14), np.float64(-2226.05))

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 349
# Absolute performance: 11427.502790346389
# SMA & threshold: 20 1.5
# Number of trades: 286
# Absolute performance: 12045.961410677046
# SMA & threshold: 20 2.0
# Number of trades: 192
# Absolute performance: 11089.394077274846
# SMA & threshold: 25 1.0
# Number of trades: 309
# Absolute performance: 12146.302771188202
# SMA & threshold: 25 1.5
# Number of trades: 228
# Absolute performance: 11241.931820371998
# SMA & threshold: 25 2.0
# Number of trades: 170
# Absolute performance: 11295.077105942677
# SMA & threshold: 30 1.0
# Number of trades: 267
# Absolute performance: 12347.164256033984
# SMA & threshold: 30 1.5
# Number of trades: 206
# Absolute performance: 11386.457592636825
# SMA & threshold: 30 2.0
# Number of trades: 144
# Absolute performance: 10840.336891108542
# SMA & threshold: 35 1.0
# Number of trades: 238
# Absolute performance: 12415.23311054349
# SMA & threshold: 35 1.5
# Number of trades: 182
# ...

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000, 0.000025)
mrbt.run_strategy(SMA=35, threshold=1.0)
# Out:
# SMA & threshold: 35 1.0
# Number of trades: 238
# Absolute performance: 12415.23311054349
# (np.float64(12415.23), np.float64(733.04))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-11', 10000, 0.000025)
mrbt.run_strategy(SMA=25, threshold=1.5)
# Out:
# SMA & threshold: 25 1.5
# Number of trades: 123
# Absolute performance: 8646.76491311295
# (np.float64(8646.76), np.float64(-6248.55))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-11', 10000, 0.000025)
mrbt.run_strategy(SMA=30, threshold=1.5)
# Out:
# SMA & threshold: 30 1.5
# Number of trades: 115
# Absolute performance: 8972.628441842475
# (np.float64(8972.63), np.float64(-5922.68))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-11', 10000, 0.000025)
mrbt.run_strategy(SMA=42, threshold=1.5)
# Out:
# SMA & threshold: 42 1.5
# Number of trades: 79
# Absolute performance: 8582.350192160182
# (np.float64(8582.35), np.float64(-6312.96))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-11', 10000, 0.000025)
mrbt.run_strategy(SMA=50, threshold=1.5)
# Out:
# SMA & threshold: 50 1.5
# Number of trades: 73
# Absolute performance: 9033.895702611175
# (np.float64(9033.9), np.float64(-5861.42))

# %%
mrbt.plot_results()

# %%
mrbt.optimize_parameters((20, 55, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 20 1.0
# Number of trades: 175
# Absolute performance: 7299.582990882641
# SMA & threshold: 20 1.5
# Number of trades: 140
# Absolute performance: 7461.045717516954
# SMA & threshold: 20 2.0
# Number of trades: 106
# Absolute performance: 8168.274841541805
# SMA & threshold: 25 1.0
# Number of trades: 155
# Absolute performance: 8492.002515233435
# SMA & threshold: 25 1.5
# Number of trades: 123
# Absolute performance: 8646.76491311295
# SMA & threshold: 25 2.0
# Number of trades: 91
# Absolute performance: 8799.434703369376
# SMA & threshold: 30 1.0
# Number of trades: 137
# Absolute performance: 9024.792465067216
# SMA & threshold: 30 1.5
# Number of trades: 115
# Absolute performance: 8972.628441842475
# SMA & threshold: 30 2.0
# Number of trades: 81
# Absolute performance: 8648.981118640622
# SMA & threshold: 35 1.0
# Number of trades: 123
# Absolute performance: 8743.563361727189
# SMA & threshold: 35 1.5
# Number of trades: 101
# ...

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-11', 10000, 0.000025)
mrbt.run_strategy(SMA=40, threshold=2.0)
# Out:
# SMA & threshold: 40 2.0
# Number of trades: 68
# Absolute performance: 9889.880258930623
# (np.float64(9889.88), np.float64(-5005.43))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H4")
mrbt.run_strategy(SMA=20, threshold=1.5)
# Out:
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# (np.float64(10241.08), np.float64(-82.6))

# %%
mrbt.plot_results()

# %%
mrbt.optimize_parameters((10, 35, 5), (1, 2.5, 0.5))
# Out:
# SMA & threshold: 10 1.0
# Number of trades: 147
# Absolute performance: 9634.314843442742
# SMA & threshold: 10 1.5
# Number of trades: 119
# Absolute performance: 9756.748210000367
# SMA & threshold: 10 2.0
# Number of trades: 63
# Absolute performance: 9966.95633461395
# SMA & threshold: 15 1.0
# Number of trades: 119
# Absolute performance: 9972.920012515697
# SMA & threshold: 15 1.5
# Number of trades: 95
# Absolute performance: 10010.8245403759
# SMA & threshold: 15 2.0
# Number of trades: 61
# Absolute performance: 9952.869268448816
# SMA & threshold: 20 1.0
# Number of trades: 93
# Absolute performance: 10084.140552505867
# SMA & threshold: 20 1.5
# Number of trades: 81
# Absolute performance: 10241.083688880759
# SMA & threshold: 20 2.0
# Number of trades: 51
# Absolute performance: 10159.619160497377
# SMA & threshold: 25 1.0
# Number of trades: 73
# Absolute performance: 9908.832871096374
# SMA & threshold: 25 1.5
# Number of trades: 61
# ...

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H1")
mrbt.run_strategy(SMA=10, threshold=1.5)
# Out:
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# (np.float64(9945.88), np.float64(-369.17))

# %%
mrbt.optimize_parameters((5, 20, 5), (1, 2, 0.5))
# Out:
# SMA & threshold: 5 1.0
# Number of trades: 958
# Absolute performance: 10298.591798317968
# SMA & threshold: 5 1.5
# Number of trades: 502
# Absolute performance: 10354.942522136376
# SMA & threshold: 10 1.0
# Number of trades: 632
# Absolute performance: 10201.741665178231
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# SMA & threshold: 15 1.0
# Number of trades: 466
# Absolute performance: 9784.800378792283
# SMA & threshold: 15 1.5
# Number of trades: 366
# Absolute performance: 9679.55778733525
# SMA & threshold: 5 1.5
# Number of trades: 502
# Absolute performance: 10354.942522136376
# ((5, 1.5), np.float64(10354.94))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-1-1', '2026-7-11', 10000, 0.000025, "H1")
mrbt.run_strategy(SMA=10, threshold=1.5)
# Out:
# SMA & threshold: 10 1.5
# Number of trades: 476
# Absolute performance: 9945.884623090815
# (np.float64(9945.88), np.float64(-369.17))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M5")
mrbt.run_strategy(SMA=3, threshold=1)
# Out:
# SMA & threshold: 3 1
# Number of trades: 2436
# Absolute performance: 9460.376643116258
# (np.float64(9460.38), np.float64(-685.18))

# %%
mrbt.optimize_parameters((2, 5, 1), (1, 1.5, 0.5))
# Out:
# SMA & threshold: 2 1.0
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 3 1.0
# Number of trades: 2436
# Absolute performance: 9460.376643116258
# SMA & threshold: 4 1.0
# Number of trades: 2617
# Absolute performance: 9450.84380740328
# SMA & threshold: 2 1.0
# Number of trades: 0
# Absolute performance: 10000.0
# ((2, 1.0), np.float64(10000.0))

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M5")
mrbt.run_strategy(SMA=2, threshold=1)
# Out:
# SMA & threshold: 2 1
# Number of trades: 0
# Absolute performance: 10000.0
# (np.float64(10000.0), np.float64(-145.56))

# %%
mrbt.plot_results()

# %%
mrbt = MR.MRVectorBacktester('USD_JPY', '2026-6-1', '2026-7-11', 10000, 0.000025, "M1")
mrbt.run_strategy(SMA=2, threshold=1)
# Out:
# SMA & threshold: 2 1
# Number of trades: 0
# Absolute performance: 10000.0
# (np.float64(10000.0), np.float64(-145.5))

# %%
mrbt.optimize_parameters((1, 3, 1), (0.5, 1, 0.5))
# Out:
# SMA & threshold: 1 0.5
# Number of trades: 0
# Absolute performance: 10000.0
# SMA & threshold: 2 0.5
# Number of trades: 20251
# Absolute performance: 6189.979526405616
# SMA & threshold: 1 0.5
# Number of trades: 0
# Absolute performance: 10000.0
# ((1, 0.5), np.float64(10000.0))

# %%
mrbt.plot_results()
