# %%
import LRVectorBacktester as LR

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2002-5-6', '2010-12-31', 10000)

# %%
lrbt.run_strategy('2020-1-1', '2020-12-31',
                  '2002-5-6', '2009-12-31', lags=3)
# Out:
# (np.float64(10000.0), np.float64(2711.27))

# %%
lrbt.plot_results()

# %%
lrbt.optimize_parameters((1,500,1))
# Out:
# /workspace/src/LRVectorBacktester.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = data['returns'].shift(lag)
# /workspace/src/LRVectorBacktester.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = data['returns'].shift(lag)
# ...

# %%
lrbt.run_strategy('2002-5-6', '2005-12-31',
                  '2002-5-6', '2009-12-31', lags=493)
# Out:
# /workspace/src/LRVectorBacktester.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = data['returns'].shift(lag)
# (np.float64(92158.98), np.float64(83632.7))

# %%
lrbt.plot_results()

# %%
lrbt.optimize_parameters((1,100,1))
# Out:
# /workspace/src/LRVectorBacktester.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = data['returns'].shift(lag)
# (40, np.float64(11181.08))

# %%
lrbt.run_strategy('2002-5-6', '2005-1-1',
                  '2005-1-1', '2007-1-1', lags=40)
# Out:
# (np.float64(11181.08), np.float64(-78.85))

# %%
lrbt.plot_results()

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2010-1-1', '2020-1-1', 10000)

# %%
lrbt.run_strategy('2010-1-1', '2020-1-1',
                  '2010-1-1', '2020-1-1', lags=3)
# Out:
# (np.float64(7425.65), np.float64(-4340.82))

# %%
lrbt.optimize_parameters((1,100,1))
# Out:
# /workspace/src/LRVectorBacktester.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = data['returns'].shift(lag)
# (93, np.float64(42563.92))

# %%
lrbt.run_strategy('2010-1-1', '2020-1-1',
                  '2010-1-1', '2020-1-1', lags=93)
# Out:
# (np.float64(42563.92), np.float64(30931.28))

# %%
lrbt.plot_results()
