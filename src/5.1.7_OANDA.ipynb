# %%
import LRVectorBacktester as LR

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2002-5-6', '2010-12-31', 10000)

# %%
lrbt.run_strategy('2002-5-6', '2005-12-31',
                  '2002-5-6', '2005-12-31', lags=3)
# Out:
# (np.float64(9638.36), np.float64(412.47))

# %%
lrbt.plot_results()

# %%
lrbt.optimize_parameters((1,50,1))
# Out:
# (49, np.float64(22691.96))

# %%
lrbt.run_strategy('2002-5-6', '2005-12-31',
                  '2006-1-1', '2009-12-31', lags=49)
# Out:
# (np.float64(11001.05), np.float64(3153.4))

# %%
lrbt.plot_results()

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000)

# %%
lrbt.run_strategy('2010-1-1', '2014-12-31',
                  '2010-1-1', '2014-12-31', lags=3)
# Out:
# (np.float64(10030.12), np.float64(-2955.59))

# %%
lrbt.optimize_parameters((1,50,1))
# Out:
# (50, np.float64(25297.22))

# %%
lrbt.run_strategy('2010-1-1', '2014-12-31',
                  '2015-1-1', '2019-12-31', lags=50)
# Out:
# (np.float64(7967.8), np.float64(-988.69))

# %%
lrbt.plot_results()

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-7', 10000)

# %%
lrbt.run_strategy('2020-1-1', '2023-12-31',
                  '2020-1-1', '2023-12-31', lags=3)
# Out:
# (np.float64(13739.34), np.float64(735.93))

# %%
lrbt.optimize_parameters((1,50,1))
# Out:
# (49, np.float64(16040.01))

# %%
lrbt.run_strategy('2020-1-1', '2023-12-31',
                  '2024-1-1', '2026-7-7', lags=49)
# Out:
# (np.float64(11616.32), np.float64(593.66))

# %%
lrbt.plot_results()
