# %%
import LRVectorBacktester as LR

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2002-5-6', '2010-12-31', 10000)

# %%
lrbt.run_strategy('2002-5-6', '2008-12-31', '2009-1-1', '2009-12-31', lags=3)
# Out:
# (np.float64(9572.03), np.float64(-681.09))

# %%
lrbt.plot_results()

# %%
lrbt.optimize_parameters((1,50,1))
# Out:
# (48, np.float64(11508.48))

# %%
lrbt.run_strategy('2002-5-6', '2008-12-31', '2009-1-1', '2009-12-31', lags=48)
# Out:
# (np.float64(11508.48), np.float64(1255.37))

# %%
lrbt.plot_results()

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2010-1-1', '2019-12-31', 10000)

# %%
lrbt.run_strategy('2010-1-1', '2018-12-31','2019-1-1', '2019-12-31', lags=3)
# Out:
# (np.float64(10143.62), np.float64(231.4))

# %%
lrbt.plot_results()

# %%
lrbt.optimize_parameters((1,50,1))
# Out:
# (8, np.float64(10632.76))

# %%
lrbt.run_strategy('2010-1-1', '2018-12-31', '2019-1-1', '2019-12-31', lags=8)
# Out:
# (np.float64(10632.76), np.float64(720.55))

# %%
lrbt.plot_results()

# %%
lrbt = LR.LRVectorBacktester('USD_JPY', '2020-1-1', '2026-7-7', 10000)

# %%
lrbt.run_strategy('2020-1-1', '2025-12-31', '2026-1-1', '2026-7-7', lags=3)
# Out:
# (np.float64(10526.54), np.float64(179.72))

# %%
lrbt.plot_results()

# %%
lrbt.optimize_parameters((1,50,1))
# Out:
# (40, np.float64(10952.87))

# %%
lrbt.run_strategy('2020-1-1', '2025-12-31', '2026-1-1', '2026-7-7', lags=40)
# Out:
# (np.float64(10952.87), np.float64(606.05))

# %%
lrbt.plot_results()
