# %%
import NeuralNetworkVectorBacktester as NN
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784177532.032776  147232 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1784177532.033217  147232 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1784177532.066451  147232 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784177532.895610  147232 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1784177532.895941  147232 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
nnbt = NN.NeuralNetworkVectorBacktester('USD_JPY', '2002-5-6',
                                    '2009-12-31', 10000)

# %%
nnbt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31', lags=3)
# Out:
# prepare_features: rows = 1182
# fit_model: valid rows = 1162
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 1328
# run_strategy: valid rows = 1308
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (np.float64(12558.92), np.float64(4487.25))

# %%
nnbt.plot_results()

# %%
nnbt.optimize_parameters(lags_range=(3,12,4),
                          start_in='2002-5-6',end_in='2004-12-31',
                          start_out='2005-1-1',end_out='2005-12-31')
# Out:
# lags= 3 mom= 5 sma= 20 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9430.56), np.float64(-2032.65))
# lags= 3 mom= 5 sma= 20 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(10401.84), np.float64(-1061.36))
# lags= 3 mom= 5 sma= 50 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# performance= (np.float64(9755.61), np.float64(-1561.93))
# lags= 3 mom= 5 sma= 50 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# performance= (np.float64(9314.65), np.float64(-2002.89))
# lags= 3 mom= 10 sma= 20 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(8961.99), np.float64(-2501.21))
# lags= 3 mom= 10 sma= 20 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(10412.6), np.float64(-1050.6))
# lags= 3 mom= 10 sma= 50 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9593.58), np.float64(-1723.96))
# lags= 3 mom= 10 sma= 50 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9678.0), np.float64(-1639.55))
# lags= 7 mom= 5 sma= 20 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(8725.55), np.float64(-2737.65))
# lags= 7 mom= 5 sma= 20 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9055.28), np.float64(-2407.92))
# lags= 7 mom= 5 sma= 50 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(8675.61), np.float64(-2641.94))
# lags= 7 mom= 5 sma= 50 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9040.0), np.float64(-2277.55))
# lags= 7 mom= 10 sma= 20 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(8853.69), np.float64(-2609.51))
# lags= 7 mom= 10 sma= 20 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9545.69), np.float64(-1917.51))
# lags= 7 mom= 10 sma= 50 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(8951.18), np.float64(-2366.36))
# lags= 7 mom= 10 sma= 50 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9470.88), np.float64(-1846.67))
# lags= 11 mom= 5 sma= 20 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# performance= (np.float64(8727.84), np.float64(-2735.36))
# lags= 11 mom= 5 sma= 20 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9729.15), np.float64(-1734.05))
# lags= 11 mom= 5 sma= 50 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# performance= (np.float64(8847.1), np.float64(-2470.45))
# lags= 11 mom= 5 sma= 50 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(8478.6), np.float64(-2838.95))
# lags= 11 mom= 10 sma= 20 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(8553.44), np.float64(-2909.76))
# lags= 11 mom= 10 sma= 20 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9176.85), np.float64(-2286.35))
# lags= 11 mom= 10 sma= 50 ema= 10 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# performance= (np.float64(8675.47), np.float64(-2642.07))
# lags= 11 mom= 10 sma= 50 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 784
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# performance= (np.float64(8523.03), np.float64(-2794.51))
# lags= 3 mom= 10 sma= 20 ema= 20 volatility= 20 range= 14
# prepare_features: rows = 834
# fit_model: valid rows = 814
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 348
# run_strategy: valid rows = 328
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# performance= (np.float64(9737.81), np.float64(-1725.39))
# (array([ 3., 10., 20., 20., 20., 14.]), np.float64(9737.81))

# %%
nnbt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31', 
                   lags=3, momentum=10, sma=20, ema=20)
# Out:
# prepare_features: rows = 1182
# fit_model: valid rows = 1162
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# prepare_features: rows = 1328
# run_strategy: valid rows = 1308
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (np.float64(10270.62), np.float64(2198.95))

# %%
nnbt.plot_results()
