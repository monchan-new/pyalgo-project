# %%
import NeuralNetworkVectorBacktester as NN
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784110183.533502  167539 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1784110183.534358  167539 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1784110183.619412  167539 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784110185.023658  167539 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1784110185.024124  167539 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
nnbt = NN.NeuralNetworkVectorBacktester('USD_JPY', '2002-5-6',
                                    '2010-12-31', 10000)

# %%
nnbt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-5-6', '2009-12-31', lags=3)
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (np.float64(10416.91), np.float64(2039.21))

# %%
nnbt.plot_results()

# %%
nnbt.optimize_parameters(lags_range=(3,51,10),
                          start_in='2002-5-6',end_in='2005-12-31',
                          start_out='2002-5-6',end_out='2005-12-31')
# Out:
# lags= 3 mom= 5 sma= 20 ema= 10 volatility= 20 range= 14
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# lags= 3 mom= 5 sma= 20 ema= 20 volatility= 20 range= 14
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 nnbt.optimize_parameters(lags_range=(3,51,10),
#       2                           start_in='2002-5-6',end_in='2005-12-31',
#       3                           start_out='2002-5-6',end_out='2005-12-31')
#
# File /workspace/src/NeuralNetworkVectorBacktester.py:338, in NeuralNetworkVectorBacktester.optimize_parameters(self, lags_range, momentum_range, sma_range, ema_range, volatility_range, range_range, start_in, end_in, start_out, end_out)
#     328 ranges = [
#     329     lags_range        if lags_range        is not None else default_ranges["lags"],
#     330     momentum_range    if momentum_range    is not None else default_ranges["momentum"],
#    (...)    334     range_range       if range_range       is not None else default_ranges["range"],
#     335 ]
#     337 # 6次元 brute
# --> 338 opt = brute(self.update_and_run, ranges, finish=None)
#     340 best_params = opt
#     341 best_perf = -self.update_and_run(opt)
#
# File ~/miniconda3/lib/python3.13/site-packages/scipy/optimize/_optimize.py:3873, in brute(func, ranges, args, Ns, full_output, finish, disp, workers)
#    3871 # iterate over input arrays, possibly in parallel
#    3872 with MapWrapper(pool=workers) as mapper:
# -> 3873     Jout = np.array(list(mapper(wrapped_func, grid)))
#    3874     if (N == 1):
#    3875         grid = (grid,)
#
# File ~/miniconda3/lib/python3.13/site-packages/scipy/optimize/_optimize.py:3945, in _Brute_Wrapper.__call__(self, x)
#    3943 def __call__(self, x):
#    3944     # flatten needed for one dimensional case.
# -> 3945     return self.f(np.asarray(x).flatten(), *self.args)
#
# File /workspace/src/NeuralNetworkVectorBacktester.py:282, in NeuralNetworkVectorBacktester.update_and_run(self, params)
#     277 range_ = int(params[5])
#     279 print('lags=',lags,'mom=',momentum, "sma=",sma,
#     280        "ema=",ema, "volatility=",volatility, "range=",range_)
# --> 282 return -self.run_strategy(
#     283     self.start_in, self.end_in,
#     284     self.start_out, self.end_out,
#     285     lags=lags,
#     286     momentum=momentum,
#     287     sma=sma,
#     288     ema=ema,
#     289     volatility=volatility,
#     290     range_=range_
#     291 )[0]
#
# File /workspace/src/NeuralNetworkVectorBacktester.py:233, in NeuralNetworkVectorBacktester.run_strategy(self, start_in, end_in, start_out, end_out, lags, momentum, sma, ema, volatility, range_)
#     231 self.lags = lags
#     232 self.feature_config = feature_config
# --> 233 self.fit_model(start_in, end_in)
#     235 # テストデータ準備
#     236 self.prepare_features(start_out, end_out)
#
# File /workspace/src/NeuralNetworkVectorBacktester.py:179, in NeuralNetworkVectorBacktester.fit_model(self, start, end)
#     176 def fit_model(self, start, end):
#     177     # lag配列をlagsの指定値に併せて自動生成
#     178     self.feature_config["lag"] = list(range(1, self.lags + 1))
# --> 179     self.prepare_features(start, end)
#     181     X = self.data_subset[self.feature_columns]
#     182     y = np.where(self.data_subset['returns'] > 0, 1, 0)
#
# File /workspace/src/NeuralNetworkVectorBacktester.py:150, in NeuralNetworkVectorBacktester.prepare_features(self, start, end)
#     147 # ★ 標準化はここでは計算しない
#     148 # ★ mu,std は fit_model() で計算済みのものを使う
#     149 if hasattr(self, "mu"):
# --> 150     data[self.feature_columns] = (data[self.feature_columns] - self.mu) / self.std
#     151 # self.mu = data[self.feature_columns].mean()
#     152 # self.std = data[self.feature_columns].std()
#     153 # data[self.feature_columns] = (data[self.feature_columns] - self.mu) /self.std
#     155 self.data_subset = data
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:4660, in DataFrame.__setitem__(self, key, value)
#    4656
#    4657         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
#    4662             self._set_item_frame_value(key, value)
#    4663         elif (
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:4699, in DataFrame._setitem_array(self, key, value)
#    4695         # Note: unlike self.iloc[:, indexer] = value, this will
#    4696         #  never try to overwrite values inplace
#    4697
#    4698         elif isinstance(value, DataFrame):
# -> 4699             check_key_length(self.columns, key, value)
#    4700             for k1, k2 in zip(key, value.columns, strict=False):
#    4701                 self[k1] = value[k2]
#    4702
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/indexers/utils.py:392, in check_key_length(columns, key, value)
#     390 if columns.is_unique:
#     391     if len(value.columns) != len(key):
# --> 392         raise ValueError("Columns must be same length as key")
#     393 # Missing keys in columns are represented as -1
#     394 elif len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
nnbt.run_strategy('2002-5-6', '2005-12-31',
                   '2006-1-1', '2009-12-31', 
                   lags=23, momentum=5, sma=20, ema=20)
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (np.float64(7774.5), np.float64(-254.68))

# %%
nnbt.plot_results()
