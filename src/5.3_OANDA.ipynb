# %%
import NeuralNetworkVectorBacktester as NN
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784874652.872846   61712 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1784874652.878942   61712 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1784874653.481867   61712 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
nnbt = NN.NeuralNetworkVectorBacktester('USD_JPY', '2002-5-6',  '2009-12-31', 10000)
# Out:
# Kelly fraction for target symbol = -3.5047539357518995

# %%
nnbt.run_strategy('2002-5-6', '2008-12-31',
                   '2009-1-1', '2009-12-31')
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# (np.float64(18802.69), np.float64(8551.89))

# %%
nnbt.plot_results()

# %%
nnbt.optimize_parameters()

# %%
nnbt.run_strategy('2002-5-6', '2008-12-31',
                   '2009-1-1', '2009-12-31', 
                   lags=11, momentum=5, sma=50, ema=10)
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# (np.float64(21658.69), np.float64(11407.89))

# %%
nnbt.plot_results()

# %%
nnbt = NN.NeuralNetworkVectorBacktester('USD_JPY',
                                        '2010-1-1', '2019-12-31', 10000)
# Out:
# Kelly fraction for target symbol = 1.8626712542887092

# %%
nnbt.run_strategy('2010-1-1', '2018-12-31',
                   '2019-1-1', '2019-12-31')
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# (np.float64(13678.43), np.float64(3766.22))

# %%
nnbt.plot_results()

# %%
nnbt.optimize_parameters()

# %%
nnbt.run_strategy('2010-1-1', '2018-12-31',
                   '2019-1-1', '2019-12-31', 
                   lags=3, momentum=5, sma=50, ema=10)
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# (np.float64(14108.58), np.float64(4196.36))

# %%
nnbt.plot_results()

# %%
nnbt = NN.NeuralNetworkVectorBacktester('USD_JPY',
                                         '2020-1-1', '2026-7-7', 10000)
# Out:
# Kelly fraction for target symbol = 6.7235635724024565

# %%
nnbt.run_strategy('2020-1-1', '2025-12-31',
                   '2026-1-1', '2026-7-7')
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# (np.float64(12411.36), np.float64(2064.54))

# %%
nnbt.plot_results()

# %%
nnbt.optimize_parameters()

# %%
nnbt.run_strategy('2020-1-1', '2025-12-31',
                   '2026-1-1', '2026-7-7', 
                   lags=11, momentum=5, sma=20, ema=10)
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...

# %%
nnbt.plot_results()

# %%
nnbt = NN.NeuralNetworkVectorBacktester('USD_JPY','2020-1-1', '2026-7-7', 10000)
# Out:
# Kelly fraction for target symbol = 6.7235635724024565

# %%
nnbt.run_strategy('2025-1-1', '2026-7-7',
                   '2025-1-1', '2027-7-7')
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# (np.float64(22994.2), np.float64(12681.55))

# %%
nnbt.plot_results()

# %%
nnbt.run_strategy('2025-1-1', '2026-6-20',
                   '2026-6-21', '2026-7-7')
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# (np.float64(10198.96), np.float64(148.87))

# %%
nnbt.plot_results()

# %%
nnbt.run_strategy('2021-1-1', '2021-11-30',
                   '2021-1-1', '2021-11-30')
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# (np.float64(13616.53), np.float64(2700.43))

# %%
nnbt.optimize_parameters()
# Out:
# lags= 3 mom= 5 sma= 20 ema= 10 volatility= 20 range= 14
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# performance= (np.float64(13616.53), np.float64(2700.43))
# lags= 3 mom= 5 sma= 20 ema= 20 volatility= 20 range= 14
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# performance= (np.float64(13593.82), np.float64(2677.72))
# ...

# %%
nnbt.run_strategy('2021-1-1', '2021-11-30',
                   '2021-12-1', '2021-12-31', 
                   lags=3, momentum=5, sma=20, ema=10)
# Out:
# /root/miniconda3/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# (np.float64(10032.58), np.float64(-173.75))

# %%
nnbt.plot_results()
